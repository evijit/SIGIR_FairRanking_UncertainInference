# %%
# Notebook modified from Kaggle: https://www.kaggle.com/shahishita23/income-classification-88-roc-auc-score

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Silencing warnings 

import warnings
warnings.filterwarnings('ignore')
pd.set_option('mode.chained_assignment',None) #Silencing the Setting with Copying Warning

# %matplotlib inline

# %%
filepath = 'adult.csv'
df = pd.read_csv(filepath)

# %%
cols_df = pd.DataFrame(df.dtypes)
num_cols = list(cols_df[cols_df[0]=='int64'].index)
cat_cols = list(cols_df[cols_df[0]=='object'].index)[:-1] #excluding target column of income 
print('Numeric variables includes:','\n',num_cols)
print('\n')
print('Categorical variables includes','\n',cat_cols)
# Out:
# Numeric variables includes:
#  ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week']
#
#
# Categorical variables includes
#  ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country']

# %%
from collections import Counter
Counter(df['race'])
# Out:
# Counter({'White': 25933,
#          'Black': 2817,
#          'Asian-Pac-Islander': 895,
#          'Other': 231,
#          'Amer-Indian-Eskimo': 286})

# %%
#Replacing '?' string with NaN values
df.replace(to_replace='?',value=np.nan,inplace=True)

# %%
df.dropna(axis=0,inplace=True)

# %%
df['income'].replace(to_replace='<=50K',value=0,inplace=True)
df['income'].replace(to_replace='>50K',value=1,inplace=True)

# %%
#Identifying categorical columns where more than 90% of observations belong only to one categroy

cat_drop = []
for i in cat_cols:
    if (df[i].value_counts(normalize=True)[0]) > 0.9:
        cat_drop.append(i)
        
print(cat_drop)
# Out:
# ['native.country']

# %%
#Similarly for numerical columns

num_drop = []
for i in num_cols:
    if df[i].value_counts(normalize=True).iloc[0] > 0.9:
        num_drop.append(i)
        
print(num_drop)
# Out:
# ['capital.gain', 'capital.loss']

# %%
X = df.drop(labels = cat_drop + num_drop + ['income'],axis=1)
y = df['income']

# %%
X.drop('education',axis=1,inplace=True)
X.drop('fnlwgt',axis=1,inplace=True)

# %%
#Listing all options other than private
to_replace = list(X['workclass'].unique())
to_replace.remove('Private')

#Placing all other categories under one bracket
X.replace(to_replace,'Non-Private',inplace=True)
X['workclass'].value_counts(normalize=True)*100
# Out:
# Private        73.887673
# Non-Private    26.112327
# Name: workclass, dtype: float64

# %%
#Let us consolidate all options where individuals were married at least once (i.e. all options other than never-married)
to_replace = list(X['marital.status'].unique())
to_replace.remove('Never-married')

#Placing all other categories under one bracket
X.replace(to_replace,'Married',inplace=True)

#Renaming the 'Never-married' category to 'Single'
X.replace('Never-married','Single',inplace=True)

# %%
#Separating the categorical variables in feature matrix that need to be encoded 

cols_X = pd.DataFrame(X.dtypes)
X_cat_cols = list(cols_X[cols_X[0]=='object'].index)
X_num_cols = list(cols_X[cols_X[0]=='int64'].index)

# %%
X = pd.get_dummies(data=X,prefix=X_cat_cols,drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.25,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train[X_num_cols] = sc.fit_transform(X_train[X_num_cols])
X_val[X_num_cols] = sc.transform(X_val[X_num_cols])

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix, roc_curve, log_loss, brier_score_loss

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(random_state=101)
log.fit(X_train,y_train)
log_y_pred = log.predict_proba(X_val)
log_roc = roc_auc_score(y_val,log_y_pred[:,-1])
print('ROC AUC score : ',log_roc)
print(log.get_params())
# Out:
# ROC AUC score :  0.8772318737812443
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': 101, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}

# %%
len(log_y_pred)
# Out:
# 7541

# %%
attrlist = []

for i,row in X_val.iterrows():
    race = ""
    gender = ""
    if row['race_Asian-Pac-Islander'] == 1:
        race = "Asian"
    elif row['race_Black'] == 1:
        race = "Black"
    elif row['race_White'] == 1:
        race = "White"
    elif row['race_Other'] == 1:
        race = "Other"
    else:
        race = "NativeAm"
        
    if row['sex_Male'] == 1:
        gender = "Male"
    else:
        gender = "Female"
        
    attrlist.append(race+"_"+gender)

# %%
log_y_pred
# Out:
# array([[0.98805573, 0.01194427],
#        [0.29615703, 0.70384297],
#        [0.96698763, 0.03301237],
#        ...,
#        [0.37971341, 0.62028659],
#        [0.33474661, 0.66525339],
#        [0.19876634, 0.80123366]])

# %%
scores = []
for y in log_y_pred:
    scores.append(y[1])

# %%
incomedata = []
for att,sc in zip(attrlist,scores):
    incomedata.append({'score':sc, 'real_attr':att})
    
incomedata.sort(key=lambda x:x['score'], reverse=True)

# %%
incomedata
# Out:
# [{'score': 0.9745225421791006, 'real_attr': 'White_Male'},
#  {'score': 0.9677706351887208, 'real_attr': 'White_Male'},
#  {'score': 0.9643494676809221, 'real_attr': 'White_Male'},
#  {'score': 0.9534162138443115, 'real_attr': 'White_Male'},
#  {'score': 0.949975071427275, 'real_attr': 'White_Male'},
#  {'score': 0.9491959088437405, 'real_attr': 'White_Male'},
#  {'score': 0.9473007637012764, 'real_attr': 'White_Male'},
#  {'score': 0.9447017430682298, 'real_attr': 'White_Male'},
#  {'score': 0.9441750334991531, 'real_attr': 'White_Male'},
#  {'score': 0.9418461852133313, 'real_attr': 'White_Male'},
#  {'score': 0.9415769228871519, 'real_attr': 'White_Male'},
#  {'score': 0.9387300935560305, 'real_attr': 'White_Male'},
#  {'score': 0.9356657240724678, 'real_attr': 'White_Male'},
#  {'score': 0.9353390560961274, 'real_attr': 'White_Male'},
#  {'score': 0.9344333663016277, 'real_attr': 'White_Male'},
#  {'score': 0.9309714195680526, 'real_attr': 'White_Female'},
#  {'score': 0.9296937256191923, 'real_attr': 'White_Female'},
#  {'score': 0.929124967915877, 'real_attr': 'White_Male'},
#  {'score': 0.9286220425298852, 'real_attr': 'White_Male'},
#  {'score': 0.9273974649103148, 'real_attr': 'White_Male'},
#  {'score': 0.9258814075014588, 'real_attr': 'White_Male'},
#  {'score': 0.9254190772836774, 'real_attr': 'White_Female'},
#  {'score': 0.9249235699625487, 'real_attr': 'White_Male'},
#  {'score': 0.9220613455055051, 'real_attr': 'White_Male'},
#  {'score': 0.9212409703986443, 'real_attr': 'White_Female'},
#  {'score': 0.9211082649644322, 'real_attr': 'White_Male'},
#  {'score': 0.9211082649644322, 'real_attr': 'White_Male'},
#  {'score': 0.9205446697592269, 'real_attr': 'White_Male'},
#  {'score': 0.9203475336436997, 'real_attr': 'White_Male'},
#  {'score': 0.9187709582000567, 'real_attr': 'White_Male'},
#  {'score': 0.9183397243965261, 'real_attr': 'White_Male'},
#  {'score': 0.9169912639335743, 'real_attr': 'White_Male'},
#  {'score': 0.916474366281681, 'real_attr': 'White_Male'},
#  {'score': 0.9135034285936051, 'real_attr': 'White_Male'},
#  {'score': 0.9135034285936051, 'real_attr': 'White_Male'},
#  {'score': 0.9134296733071342, 'real_attr': 'White_Male'},
#  {'score': 0.9105257515475239, 'real_attr': 'White_Male'},
#  {'score': 0.909579597625591, 'real_attr': 'White_Male'},
#  {'score': 0.9089565337591486, 'real_attr': 'White_Female'},
#  {'score': 0.9089381396582104, 'real_attr': 'White_Male'},
#  {'score': 0.9080961007242114, 'real_attr': 'White_Male'},
#  {'score': 0.9058919048497941, 'real_attr': 'White_Male'},
#  {'score': 0.9058123284374121, 'real_attr': 'White_Male'},
#  {'score': 0.9055287313741478, 'real_attr': 'White_Male'},
#  {'score': 0.9047721786081215, 'real_attr': 'White_Female'},
#  {'score': 0.9039466885609702, 'real_attr': 'White_Male'},
#  {'score': 0.9030595615234537, 'real_attr': 'White_Male'},
#  {'score': 0.9028119579666499, 'real_attr': 'White_Male'},
#  {'score': 0.9015744971617227, 'real_attr': 'White_Female'},
#  {'score': 0.9011062650615407, 'real_attr': 'White_Male'},
#  {'score': 0.9011062650615407, 'real_attr': 'White_Male'},
#  {'score': 0.9002871507519894, 'real_attr': 'White_Male'},
#  {'score': 0.9001171704223329, 'real_attr': 'White_Male'},
#  {'score': 0.9001171704223329, 'real_attr': 'White_Male'},
#  {'score': 0.896630043892941, 'real_attr': 'White_Male'},
#  {'score': 0.8964151374903356, 'real_attr': 'White_Male'},
#  {'score': 0.8963146572656185, 'real_attr': 'White_Female'},
#  {'score': 0.8956646561936936, 'real_attr': 'White_Male'},
#  {'score': 0.8951780407400177, 'real_attr': 'White_Female'},
#  {'score': 0.894562322083342, 'real_attr': 'White_Male'},
#  {'score': 0.8943216766930403, 'real_attr': 'White_Male'},
#  {'score': 0.8942235708563161, 'real_attr': 'White_Female'},
#  {'score': 0.8935888275928211, 'real_attr': 'White_Male'},
#  {'score': 0.8933603379946785, 'real_attr': 'White_Male'},
#  {'score': 0.8920169271291851, 'real_attr': 'White_Female'},
#  {'score': 0.8918488744832255, 'real_attr': 'White_Male'},
#  {'score': 0.8913384378846652, 'real_attr': 'White_Male'},
#  {'score': 0.891126407224621, 'real_attr': 'White_Male'},
#  {'score': 0.8910473266155275, 'real_attr': 'White_Male'},
#  {'score': 0.8901709189280004, 'real_attr': 'White_Male'},
#  {'score': 0.8899699110702577, 'real_attr': 'White_Male'},
#  {'score': 0.8898600640192197, 'real_attr': 'White_Male'},
#  {'score': 0.8897346096835091, 'real_attr': 'White_Male'},
#  {'score': 0.889674486890514, 'real_attr': 'White_Male'},
#  {'score': 0.889488635910903, 'real_attr': 'White_Male'},
#  {'score': 0.8891295972949579, 'real_attr': 'Asian_Male'},
#  {'score': 0.8889250890779521, 'real_attr': 'White_Male'},
#  {'score': 0.8888748622510645, 'real_attr': 'White_Male'},
#  {'score': 0.8883473019195081, 'real_attr': 'White_Male'},
#  {'score': 0.887296019565493, 'real_attr': 'White_Male'},
#  {'score': 0.8870557256930601, 'real_attr': 'White_Male'},
#  {'score': 0.8867490503511369, 'real_attr': 'White_Male'},
#  {'score': 0.8847974193836212, 'real_attr': 'White_Male'},
#  {'score': 0.883729237697151, 'real_attr': 'White_Male'},
#  {'score': 0.8830769337517109, 'real_attr': 'White_Male'},
#  {'score': 0.8830642683975849, 'real_attr': 'White_Female'},
#  {'score': 0.8825889904091566, 'real_attr': 'White_Male'},
#  {'score': 0.8824199892248213, 'real_attr': 'White_Male'},
#  {'score': 0.8822717962909183, 'real_attr': 'White_Male'},
#  {'score': 0.8808063117423415, 'real_attr': 'White_Male'},
#  {'score': 0.8806257571269432, 'real_attr': 'White_Female'},
#  {'score': 0.8805582583644871, 'real_attr': 'White_Male'},
#  {'score': 0.8805047567388565, 'real_attr': 'White_Male'},
#  {'score': 0.880457358675062, 'real_attr': 'White_Male'},
#  {'score': 0.8804402775876919, 'real_attr': 'White_Male'},
#  {'score': 0.8795474756484466, 'real_attr': 'White_Male'},
#  {'score': 0.8794361724009128, 'real_attr': 'White_Male'},
#  {'score': 0.8791363059777676, 'real_attr': 'White_Male'},
#  {'score': 0.8786267173568838, 'real_attr': 'White_Male'},
#  {'score': 0.8784602679089343, 'real_attr': 'White_Male'},
#  {'score': 0.8784602679089343, 'real_attr': 'White_Male'},
#  {'score': 0.877645172317631, 'real_attr': 'White_Male'},
#  {'score': 0.8769016414310263, 'real_attr': 'White_Female'},
#  {'score': 0.8764819905826431, 'real_attr': 'White_Male'},
#  {'score': 0.8764407970470014, 'real_attr': 'White_Male'},
#  {'score': 0.8764407970470014, 'real_attr': 'White_Male'},
#  {'score': 0.8749163201610887, 'real_attr': 'White_Male'},
#  {'score': 0.8728464874350353, 'real_attr': 'White_Male'},
#  {'score': 0.8727900305018557, 'real_attr': 'White_Male'},
#  {'score': 0.8723913073910251, 'real_attr': 'White_Female'},
#  {'score': 0.8722304216582093, 'real_attr': 'Asian_Male'},
#  {'score': 0.8717128898593992, 'real_attr': 'White_Male'},
#  {'score': 0.8715734092894423, 'real_attr': 'Asian_Male'},
#  {'score': 0.8713461401901286, 'real_attr': 'White_Male'},
#  {'score': 0.8710767810009694, 'real_attr': 'White_Male'},
#  {'score': 0.8708141858173998, 'real_attr': 'White_Male'},
#  {'score': 0.8706902130408566, 'real_attr': 'White_Male'},
#  {'score': 0.8706902130408566, 'real_attr': 'White_Male'},
#  {'score': 0.8702585909332037, 'real_attr': 'White_Male'},
#  {'score': 0.8695979488409101, 'real_attr': 'White_Male'},
#  {'score': 0.8691980504108351, 'real_attr': 'White_Male'},
#  {'score': 0.8691980504108351, 'real_attr': 'White_Male'},
#  {'score': 0.8689344493987429, 'real_attr': 'White_Male'},
#  {'score': 0.8687621983553536, 'real_attr': 'White_Male'},
#  {'score': 0.8683166297013056, 'real_attr': 'White_Male'},
#  {'score': 0.8680169921470942, 'real_attr': 'White_Male'},
#  {'score': 0.8676611805422029, 'real_attr': 'White_Male'},
#  {'score': 0.8674172978251183, 'real_attr': 'Other_Male'},
#  {'score': 0.867394954835381, 'real_attr': 'White_Male'},
#  {'score': 0.867394954835381, 'real_attr': 'White_Male'},
#  {'score': 0.8672654230320722, 'real_attr': 'White_Female'},
#  {'score': 0.8669540142489549, 'real_attr': 'White_Male'},
#  {'score': 0.8668292014523783, 'real_attr': 'White_Female'},
#  {'score': 0.8666383482742667, 'real_attr': 'White_Male'},
#  {'score': 0.8659296806714317, 'real_attr': 'White_Male'},
#  {'score': 0.865096033194638, 'real_attr': 'White_Male'},
#  {'score': 0.8650885086697916, 'real_attr': 'White_Female'},
#  {'score': 0.8647133028843897, 'real_attr': 'White_Male'},
#  {'score': 0.8646698030448683, 'real_attr': 'Asian_Male'},
#  {'score': 0.864443199940793, 'real_attr': 'White_Male'},
#  {'score': 0.8643604014736503, 'real_attr': 'White_Male'},
#  {'score': 0.8638511479700022, 'real_attr': 'White_Male'},
#  {'score': 0.863674430590481, 'real_attr': 'White_Male'},
#  {'score': 0.8634509820344161, 'real_attr': 'White_Female'},
#  {'score': 0.8626707414171724, 'real_attr': 'White_Male'},
#  {'score': 0.8625322613373899, 'real_attr': 'White_Male'},
#  {'score': 0.8625322613373899, 'real_attr': 'White_Male'},
#  {'score': 0.8622927302993909, 'real_attr': 'Black_Female'},
#  {'score': 0.8620777223118262, 'real_attr': 'White_Male'},
#  {'score': 0.8620172398421496, 'real_attr': 'White_Male'},
#  {'score': 0.8616125472194529, 'real_attr': 'White_Female'},
#  {'score': 0.8613867890800988, 'real_attr': 'White_Female'},
#  {'score': 0.8609507232335458, 'real_attr': 'Asian_Female'},
#  {'score': 0.8606583286023866, 'real_attr': 'Asian_Male'},
#  {'score': 0.8605910029546918, 'real_attr': 'White_Male'},
#  {'score': 0.8605910029546918, 'real_attr': 'White_Male'},
#  {'score': 0.8601985976849845, 'real_attr': 'Asian_Male'},
#  {'score': 0.8594272047142603, 'real_attr': 'White_Male'},
#  {'score': 0.8594272047142603, 'real_attr': 'White_Male'},
#  {'score': 0.8594272047142603, 'real_attr': 'White_Male'},
#  {'score': 0.8594272047142603, 'real_attr': 'White_Male'},
#  {'score': 0.8590841197784097, 'real_attr': 'Asian_Female'},
#  {'score': 0.8588620547158075, 'real_attr': 'White_Male'},
#  {'score': 0.8580766606352702, 'real_attr': 'White_Male'},
#  {'score': 0.8580068579070939, 'real_attr': 'White_Female'},
#  {'score': 0.8570442877292784, 'real_attr': 'White_Male'},
#  {'score': 0.8563785013631429, 'real_attr': 'White_Male'},
#  {'score': 0.8563785013631429, 'real_attr': 'White_Male'},
#  {'score': 0.8563327668263604, 'real_attr': 'Asian_Male'},
#  {'score': 0.8558217344016205, 'real_attr': 'White_Female'},
#  {'score': 0.8554721082275789, 'real_attr': 'White_Male'},
#  {'score': 0.855433075248126, 'real_attr': 'White_Female'},
#  {'score': 0.8554254468046462, 'real_attr': 'White_Male'},
#  {'score': 0.8551078082729591, 'real_attr': 'White_Male'},
#  {'score': 0.854950976466717, 'real_attr': 'White_Male'},
#  {'score': 0.8546383284947967, 'real_attr': 'White_Male'},
#  {'score': 0.8546061360820383, 'real_attr': 'White_Male'},
#  {'score': 0.8545136755779766, 'real_attr': 'White_Male'},
#  {'score': 0.8543263322706421, 'real_attr': 'White_Female'},
#  {'score': 0.8537863305184915, 'real_attr': 'White_Male'},
#  {'score': 0.8536698114388527, 'real_attr': 'White_Male'},
#  {'score': 0.8533714419051608, 'real_attr': 'White_Male'},
#  {'score': 0.8532360441192296, 'real_attr': 'White_Female'},
#  {'score': 0.8528131144111111, 'real_attr': 'White_Male'},
#  {'score': 0.852639371129011, 'real_attr': 'White_Male'},
#  {'score': 0.8524785491889365, 'real_attr': 'White_Male'},
#  {'score': 0.8524014822404989, 'real_attr': 'White_Male'},
#  {'score': 0.852386049496272, 'real_attr': 'White_Female'},
#  {'score': 0.8522200094755574, 'real_attr': 'White_Male'},
#  {'score': 0.8520456875398024, 'real_attr': 'White_Male'},
#  {'score': 0.8515436596143622, 'real_attr': 'White_Female'},
#  {'score': 0.8515244862460293, 'real_attr': 'White_Male'},
#  {'score': 0.8512587325543828, 'real_attr': 'White_Male'},
#  {'score': 0.8509902532963798, 'real_attr': 'White_Female'},
#  {'score': 0.8507583544593333, 'real_attr': 'White_Male'},
#  {'score': 0.8506159319073153, 'real_attr': 'White_Male'},
#  {'score': 0.8501992343173099, 'real_attr': 'White_Male'},
#  {'score': 0.8499940488799972, 'real_attr': 'White_Male'},
#  {'score': 0.8498390661542383, 'real_attr': 'White_Male'},
#  {'score': 0.8496460616704091, 'real_attr': 'White_Male'},
#  {'score': 0.8492765465011775, 'real_attr': 'White_Female'},
#  {'score': 0.8491468609748432, 'real_attr': 'White_Male'},
#  {'score': 0.8487997879712312, 'real_attr': 'White_Male'},
#  {'score': 0.8482926119950167, 'real_attr': 'White_Male'},
#  {'score': 0.8475805387517079, 'real_attr': 'White_Female'},
#  {'score': 0.8475451839195175, 'real_attr': 'White_Male'},
#  {'score': 0.8473220231847843, 'real_attr': 'White_Male'},
#  {'score': 0.8472893694760986, 'real_attr': 'White_Male'},
#  {'score': 0.8470072412721078, 'real_attr': 'White_Male'},
#  {'score': 0.8468650631722539, 'real_attr': 'White_Male'},
#  {'score': 0.8468168410812211, 'real_attr': 'Asian_Male'},
#  {'score': 0.8459757153668372, 'real_attr': 'White_Male'},
#  {'score': 0.8458347220540249, 'real_attr': 'White_Female'},
#  {'score': 0.8456805008512812, 'real_attr': 'Asian_Male'},
#  {'score': 0.8456072365825441, 'real_attr': 'White_Male'},
#  {'score': 0.8455680344993892, 'real_attr': 'White_Male'},
#  {'score': 0.8453445967020684, 'real_attr': 'White_Male'},
#  {'score': 0.8452523836242961, 'real_attr': 'Black_Female'},
#  {'score': 0.8445952692349512, 'real_attr': 'White_Male'},
#  {'score': 0.8445558574357093, 'real_attr': 'White_Male'},
#  {'score': 0.8442148955285301, 'real_attr': 'White_Male'},
#  {'score': 0.8440765806683527, 'real_attr': 'White_Male'},
#  {'score': 0.844052625895705, 'real_attr': 'White_Male'},
#  {'score': 0.8440096326236345, 'real_attr': 'White_Male'},
#  {'score': 0.8438775302188658, 'real_attr': 'White_Male'},
#  {'score': 0.8438429818349269, 'real_attr': 'White_Male'},
#  {'score': 0.8438429818349269, 'real_attr': 'White_Male'},
#  {'score': 0.8435107734562081, 'real_attr': 'White_Male'},
#  {'score': 0.8431463307631586, 'real_attr': 'Asian_Male'},
#  {'score': 0.843004787514278, 'real_attr': 'White_Male'},
#  {'score': 0.8425913432418893, 'real_attr': 'White_Male'},
#  {'score': 0.8424812561104228, 'real_attr': 'Black_Male'},
#  {'score': 0.8414382287046668, 'real_attr': 'Other_Male'},
#  {'score': 0.8413193079805396, 'real_attr': 'White_Male'},
#  {'score': 0.8411240183081562, 'real_attr': 'White_Female'},
#  {'score': 0.8410098006187026, 'real_attr': 'White_Male'},
#  {'score': 0.8410098006187026, 'real_attr': 'White_Male'},
#  {'score': 0.8407566440756009, 'real_attr': 'White_Male'},
#  {'score': 0.8400245343292392, 'real_attr': 'White_Male'},
#  {'score': 0.8395838643516136, 'real_attr': 'White_Male'},
#  {'score': 0.8392030005705268, 'real_attr': 'White_Male'},
#  {'score': 0.8388787881179504, 'real_attr': 'White_Male'},
#  {'score': 0.8385781207750744, 'real_attr': 'White_Male'},
#  {'score': 0.8382830230988442, 'real_attr': 'White_Female'},
#  {'score': 0.8374314385914476, 'real_attr': 'White_Male'},
#  {'score': 0.8370303278115443, 'real_attr': 'White_Male'},
#  {'score': 0.8370303278115443, 'real_attr': 'White_Male'},
#  {'score': 0.8369521406885305, 'real_attr': 'White_Female'},
#  {'score': 0.8365134721539211, 'real_attr': 'White_Male'},
#  {'score': 0.8362323278529018, 'real_attr': 'White_Male'},
#  {'score': 0.8339226879887325, 'real_attr': 'White_Male'},
#  {'score': 0.8334343413178038, 'real_attr': 'White_Male'},
#  {'score': 0.8334343413178038, 'real_attr': 'White_Male'},
#  {'score': 0.8333273104899738, 'real_attr': 'White_Male'},
#  {'score': 0.8331540831287524, 'real_attr': 'Asian_Male'},
#  {'score': 0.8329606297079466, 'real_attr': 'White_Male'},
#  {'score': 0.8327975088023453, 'real_attr': 'Asian_Male'},
#  {'score': 0.8327784594193866, 'real_attr': 'White_Male'},
#  {'score': 0.8321646506446168, 'real_attr': 'White_Female'},
#  {'score': 0.8320880701075997, 'real_attr': 'White_Male'},
#  {'score': 0.8319176930807664, 'real_attr': 'Black_Male'},
#  {'score': 0.8312769247139019, 'real_attr': 'White_Male'},
#  {'score': 0.8311626086771039, 'real_attr': 'White_Male'},
#  {'score': 0.8309961458533298, 'real_attr': 'White_Female'},
#  {'score': 0.8308969253630182, 'real_attr': 'White_Male'},
#  {'score': 0.8307393198182637, 'real_attr': 'White_Male'},
#  {'score': 0.8307393198182637, 'real_attr': 'White_Male'},
#  {'score': 0.8298735424386587, 'real_attr': 'White_Male'},
#  {'score': 0.8298735424386587, 'real_attr': 'White_Male'},
#  {'score': 0.8296427502704264, 'real_attr': 'Black_Male'},
#  {'score': 0.8292666209157888, 'real_attr': 'White_Male'},
#  {'score': 0.8292666209157888, 'real_attr': 'White_Male'},
#  {'score': 0.8290476557267005, 'real_attr': 'White_Male'},
#  {'score': 0.8286236397603836, 'real_attr': 'White_Male'},
#  {'score': 0.8284917794132909, 'real_attr': 'White_Male'},
#  {'score': 0.8284383969764185, 'real_attr': 'White_Male'},
#  {'score': 0.8284383969764185, 'real_attr': 'White_Male'},
#  {'score': 0.8284015672392296, 'real_attr': 'White_Male'},
#  {'score': 0.8283506716314434, 'real_attr': 'White_Female'},
#  {'score': 0.8273317581365308, 'real_attr': 'Black_Male'},
#  {'score': 0.8273305835717661, 'real_attr': 'White_Male'},
#  {'score': 0.8271697806379755, 'real_attr': 'Black_Male'},
#  {'score': 0.8271328573729754, 'real_attr': 'White_Male'},
#  {'score': 0.8270509029286169, 'real_attr': 'White_Female'},
#  {'score': 0.8269718419386759, 'real_attr': 'White_Female'},
#  {'score': 0.8268189953782856, 'real_attr': 'White_Male'},
#  {'score': 0.8268154844350865, 'real_attr': 'White_Male'},
#  {'score': 0.8260793792188699, 'real_attr': 'White_Male'},
#  {'score': 0.8258571847859748, 'real_attr': 'White_Male'},
#  {'score': 0.8255350318511747, 'real_attr': 'White_Male'},
#  {'score': 0.8254738862867846, 'real_attr': 'White_Male'},
#  {'score': 0.8254141091564964, 'real_attr': 'White_Male'},
#  {'score': 0.8251405895138821, 'real_attr': 'White_Male'},
#  {'score': 0.8248311363461067, 'real_attr': 'White_Male'},
#  {'score': 0.8237008736182172, 'real_attr': 'White_Male'},
#  {'score': 0.823564984394585, 'real_attr': 'White_Male'},
#  {'score': 0.8232905865532356, 'real_attr': 'White_Male'},
#  {'score': 0.8231547988804817, 'real_attr': 'White_Male'},
#  {'score': 0.8227157159938693, 'real_attr': 'White_Male'},
#  {'score': 0.8227157159938693, 'real_attr': 'White_Male'},
#  {'score': 0.8225549911479295, 'real_attr': 'White_Male'},
#  {'score': 0.8218798503388742, 'real_attr': 'White_Male'},
#  {'score': 0.8217959420508362, 'real_attr': 'White_Female'},
#  {'score': 0.8213013865253158, 'real_attr': 'White_Male'},
#  {'score': 0.8212629004106995, 'real_attr': 'White_Male'},
#  {'score': 0.821098249152359, 'real_attr': 'White_Male'},
#  {'score': 0.8210235270061553, 'real_attr': 'White_Male'},
#  {'score': 0.820811003759344, 'real_attr': 'Black_Male'},
#  {'score': 0.82068287013373, 'real_attr': 'White_Male'},
#  {'score': 0.8204667946049643, 'real_attr': 'White_Male'},
#  {'score': 0.8196051689977946, 'real_attr': 'White_Male'},
#  {'score': 0.8193940105414006, 'real_attr': 'White_Male'},
#  {'score': 0.8190950783069888, 'real_attr': 'Black_Female'},
#  {'score': 0.818975546948105, 'real_attr': 'White_Male'},
#  {'score': 0.8186948693138213, 'real_attr': 'White_Male'},
#  {'score': 0.8184277806046346, 'real_attr': 'White_Male'},
#  {'score': 0.8183382576960684, 'real_attr': 'White_Male'},
#  {'score': 0.8173772509221172, 'real_attr': 'White_Male'},
#  {'score': 0.8172555876607739, 'real_attr': 'White_Male'},
#  {'score': 0.8172555876607739, 'real_attr': 'White_Male'},
#  {'score': 0.8167290024987112, 'real_attr': 'White_Male'},
#  {'score': 0.8163819996781648, 'real_attr': 'White_Male'},
#  {'score': 0.8163819996781648, 'real_attr': 'White_Male'},
#  {'score': 0.8162960803680649, 'real_attr': 'White_Female'},
#  {'score': 0.8152381444896892, 'real_attr': 'White_Male'},
#  {'score': 0.8149925200788198, 'real_attr': 'White_Male'},
#  {'score': 0.8149736102114865, 'real_attr': 'Asian_Male'},
#  {'score': 0.8149060980073703, 'real_attr': 'White_Female'},
#  {'score': 0.8149060980073703, 'real_attr': 'White_Female'},
#  {'score': 0.8146205389357555, 'real_attr': 'White_Female'},
#  {'score': 0.8143571030663317, 'real_attr': 'White_Male'},
#  {'score': 0.8143571030663317, 'real_attr': 'White_Male'},
#  {'score': 0.8142120786079718, 'real_attr': 'White_Male'},
#  {'score': 0.8132035199586034, 'real_attr': 'White_Male'},
#  {'score': 0.8128912562583837, 'real_attr': 'White_Male'},
#  {'score': 0.8128912562583837, 'real_attr': 'White_Male'},
#  {'score': 0.8128040780833402, 'real_attr': 'White_Female'},
#  {'score': 0.8126033035543354, 'real_attr': 'White_Male'},
#  {'score': 0.812283522162853, 'real_attr': 'White_Male'},
#  {'score': 0.811820539236439, 'real_attr': 'White_Male'},
#  {'score': 0.8117774671975165, 'real_attr': 'White_Male'},
#  {'score': 0.8117125996790733, 'real_attr': 'White_Male'},
#  {'score': 0.8117125996790733, 'real_attr': 'White_Male'},
#  {'score': 0.8116348567152262, 'real_attr': 'White_Male'},
#  {'score': 0.8111918428104148, 'real_attr': 'White_Male'},
#  {'score': 0.810230737647293, 'real_attr': 'White_Male'},
#  {'score': 0.8100637618973687, 'real_attr': 'Black_Female'},
#  {'score': 0.8099396478236098, 'real_attr': 'White_Male'},
#  {'score': 0.8099396478236098, 'real_attr': 'White_Male'},
#  {'score': 0.809861344293069, 'real_attr': 'White_Male'},
#  {'score': 0.8097570620323005, 'real_attr': 'White_Male'},
#  {'score': 0.8094616348112045, 'real_attr': 'White_Male'},
#  {'score': 0.8092521341729702, 'real_attr': 'White_Male'},
#  {'score': 0.8092155974688179, 'real_attr': 'White_Male'},
#  {'score': 0.8089122009932372, 'real_attr': 'Asian_Male'},
#  {'score': 0.8088056114496833, 'real_attr': 'White_Male'},
#  {'score': 0.8081539471907705, 'real_attr': 'White_Male'},
#  {'score': 0.8081539471907705, 'real_attr': 'White_Male'},
#  {'score': 0.8078677435889914, 'real_attr': 'White_Male'},
#  {'score': 0.8077814703346007, 'real_attr': 'White_Male'},
#  {'score': 0.8077556585912263, 'real_attr': 'Black_Male'},
#  {'score': 0.8074622887249293, 'real_attr': 'White_Male'},
#  {'score': 0.8067962348204876, 'real_attr': 'White_Male'},
#  {'score': 0.8067962348204876, 'real_attr': 'White_Male'},
#  {'score': 0.8067169452784474, 'real_attr': 'White_Male'},
#  {'score': 0.8061008558567232, 'real_attr': 'White_Male'},
#  {'score': 0.8058914120083082, 'real_attr': 'White_Male'},
#  {'score': 0.805884523127033, 'real_attr': 'White_Male'},
#  {'score': 0.8056588971479278, 'real_attr': 'White_Male'},
#  {'score': 0.8050657184592991, 'real_attr': 'White_Male'},
#  {'score': 0.8047424964481552, 'real_attr': 'Black_Male'},
#  {'score': 0.8047313690095035, 'real_attr': 'White_Male'},
#  {'score': 0.8045256371325311, 'real_attr': 'White_Male'},
#  {'score': 0.8041975821023966, 'real_attr': 'White_Female'},
#  {'score': 0.8039228996891272, 'real_attr': 'White_Male'},
#  {'score': 0.8039228996891272, 'real_attr': 'White_Male'},
#  {'score': 0.8036244792756487, 'real_attr': 'White_Male'},
#  {'score': 0.8034685243476408, 'real_attr': 'White_Female'},
#  {'score': 0.8034474683561329, 'real_attr': 'White_Male'},
#  {'score': 0.803367139450601, 'real_attr': 'White_Male'},
#  {'score': 0.8026209016269723, 'real_attr': 'White_Male'},
#  {'score': 0.8026209016269723, 'real_attr': 'White_Male'},
#  {'score': 0.8023332067954418, 'real_attr': 'White_Female'},
#  {'score': 0.8015348186385335, 'real_attr': 'White_Male'},
#  {'score': 0.8015006036356683, 'real_attr': 'White_Male'},
#  {'score': 0.8013146472256149, 'real_attr': 'White_Male'},
#  {'score': 0.8013146472256149, 'real_attr': 'White_Male'},
#  {'score': 0.8012336623008494, 'real_attr': 'White_Male'},
#  {'score': 0.8011423813071105, 'real_attr': 'White_Female'},
#  {'score': 0.8011006050068662, 'real_attr': 'White_Female'},
#  {'score': 0.8006044149359335, 'real_attr': 'White_Male'},
#  {'score': 0.7998503045053343, 'real_attr': 'White_Male'},
#  {'score': 0.7994679744469327, 'real_attr': 'White_Male'},
#  {'score': 0.7993663129533346, 'real_attr': 'Asian_Male'},
#  {'score': 0.7987253043137749, 'real_attr': 'White_Male'},
#  {'score': 0.797526359116917, 'real_attr': 'White_Male'},
#  {'score': 0.7974093068833544, 'real_attr': 'White_Male'},
#  {'score': 0.7973249725129782, 'real_attr': 'Asian_Male'},
#  {'score': 0.7966714655936291, 'real_attr': 'White_Male'},
#  {'score': 0.7962063022164971, 'real_attr': 'White_Male'},
#  {'score': 0.796123764873934, 'real_attr': 'White_Male'},
#  {'score': 0.7959213401882776, 'real_attr': 'Asian_Male'},
#  {'score': 0.7954983812128328, 'real_attr': 'White_Female'},
#  {'score': 0.7950939338056543, 'real_attr': 'White_Male'},
#  {'score': 0.7950110619370359, 'real_attr': 'White_Male'},
#  {'score': 0.7946332784113807, 'real_attr': 'White_Male'},
#  {'score': 0.7946090303249479, 'real_attr': 'White_Female'},
#  {'score': 0.794550268377117, 'real_attr': 'White_Male'},
#  {'score': 0.794539743548771, 'real_attr': 'White_Female'},
#  {'score': 0.7943243367812809, 'real_attr': 'White_Male'},
#  {'score': 0.7942306976465724, 'real_attr': 'White_Female'},
#  {'score': 0.7940227600591622, 'real_attr': 'White_Male'},
#  {'score': 0.7940150508710464, 'real_attr': 'White_Male'},
#  {'score': 0.7939464020268878, 'real_attr': 'White_Male'},
#  {'score': 0.7939318557494687, 'real_attr': 'White_Male'},
#  {'score': 0.7937092329042976, 'real_attr': 'White_Male'},
#  {'score': 0.793368844523971, 'real_attr': 'White_Male'},
#  {'score': 0.7933020021883213, 'real_attr': 'White_Female'},
#  {'score': 0.7931209267848665, 'real_attr': 'White_Male'},
#  {'score': 0.792930327528822, 'real_attr': 'White_Female'},
#  {'score': 0.7928103032610214, 'real_attr': 'White_Male'},
#  {'score': 0.7928103032610214, 'real_attr': 'White_Male'},
#  {'score': 0.7924726485620842, 'real_attr': 'White_Male'},
#  {'score': 0.7924295228109616, 'real_attr': 'White_Male'},
#  {'score': 0.7924295228109616, 'real_attr': 'White_Male'},
#  {'score': 0.792345854785831, 'real_attr': 'White_Male'},
#  {'score': 0.7920343726606472, 'real_attr': 'White_Male'},
#  {'score': 0.7919406921388105, 'real_attr': 'White_Male'},
#  {'score': 0.7919334359769244, 'real_attr': 'White_Male'},
#  {'score': 0.7914528635795903, 'real_attr': 'White_Male'},
#  {'score': 0.7907306454017884, 'real_attr': 'Black_Male'},
#  {'score': 0.7905921407606616, 'real_attr': 'White_Male'},
#  {'score': 0.7898429293167775, 'real_attr': 'White_Female'},
#  {'score': 0.7896239021722543, 'real_attr': 'White_Male'},
#  {'score': 0.7894167309438178, 'real_attr': 'Asian_Male'},
#  {'score': 0.7891542104895483, 'real_attr': 'White_Male'},
#  {'score': 0.7891542104895483, 'real_attr': 'White_Male'},
#  {'score': 0.7891542104895483, 'real_attr': 'White_Male'},
#  {'score': 0.7891542104895483, 'real_attr': 'White_Male'},
#  {'score': 0.7891542104895483, 'real_attr': 'White_Male'},
#  {'score': 0.7891110942680352, 'real_attr': 'White_Male'},
#  {'score': 0.7890045836179087, 'real_attr': 'White_Female'},
#  {'score': 0.7886523835279752, 'real_attr': 'White_Male'},
#  {'score': 0.7886086756636385, 'real_attr': 'White_Male'},
#  {'score': 0.7885816219694989, 'real_attr': 'White_Male'},
#  {'score': 0.7882079106639612, 'real_attr': 'White_Male'},
#  {'score': 0.7880985448091723, 'real_attr': 'White_Male'},
#  {'score': 0.7880135980538081, 'real_attr': 'White_Male'},
#  {'score': 0.7876263635129529, 'real_attr': 'White_Male'},
#  {'score': 0.7876263635129529, 'real_attr': 'White_Male'},
#  {'score': 0.7876263635129529, 'real_attr': 'White_Male'},
#  {'score': 0.7875412784990564, 'real_attr': 'White_Male'},
#  {'score': 0.7874585365179751, 'real_attr': 'White_Male'},
#  {'score': 0.7872677798867842, 'real_attr': 'Black_Male'},
#  {'score': 0.7869654922282583, 'real_attr': 'White_Male'},
#  {'score': 0.7866481126660159, 'real_attr': 'White_Male'},
#  {'score': 0.7865352618192771, 'real_attr': 'White_Male'},
#  {'score': 0.7859417232820322, 'real_attr': 'White_Male'},
#  {'score': 0.7852819836666394, 'real_attr': 'White_Male'},
#  {'score': 0.7847291629928214, 'real_attr': 'White_Male'},
#  {'score': 0.7847017483504835, 'real_attr': 'White_Male'},
#  {'score': 0.7846110252852648, 'real_attr': 'White_Male'},
#  {'score': 0.7843819202839802, 'real_attr': 'White_Male'},
#  {'score': 0.7839117126973565, 'real_attr': 'White_Male'},
#  {'score': 0.7837417562154899, 'real_attr': 'White_Male'},
#  {'score': 0.783306520163448, 'real_attr': 'White_Male'},
#  {'score': 0.7831362193691648, 'real_attr': 'White_Male'},
#  {'score': 0.782742531712876, 'real_attr': 'White_Male'},
#  {'score': 0.782740527982631, 'real_attr': 'Asian_Female'},
#  {'score': 0.7826560299826879, 'real_attr': 'White_Male'},
#  {'score': 0.7824438875634624, 'real_attr': 'Asian_Male'},
#  {'score': 0.7819729811634942, 'real_attr': 'White_Female'},
#  {'score': 0.7819473044959577, 'real_attr': 'White_Male'},
#  {'score': 0.7815634121660003, 'real_attr': 'White_Female'},
#  {'score': 0.7815634121660003, 'real_attr': 'White_Female'},
#  {'score': 0.7813271295279757, 'real_attr': 'White_Female'},
#  {'score': 0.7807882703713901, 'real_attr': 'White_Female'},
#  {'score': 0.7805784806351151, 'real_attr': 'White_Male'},
#  {'score': 0.7805784806351151, 'real_attr': 'White_Male'},
#  {'score': 0.7803592737530544, 'real_attr': 'White_Male'},
#  {'score': 0.7803592737530544, 'real_attr': 'White_Male'},
#  {'score': 0.7802945899401486, 'real_attr': 'White_Male'},
#  {'score': 0.7801559706898726, 'real_attr': 'White_Female'},
#  {'score': 0.7800942180975617, 'real_attr': 'White_Male'},
#  {'score': 0.7799700507314903, 'real_attr': 'White_Male'},
#  {'score': 0.7797264734998635, 'real_attr': 'Black_Male'},
#  {'score': 0.7797056121002518, 'real_attr': 'Asian_Male'},
#  {'score': 0.779356926061994, 'real_attr': 'White_Male'},
#  {'score': 0.7788383158715233, 'real_attr': 'White_Male'},
#  {'score': 0.7788383158715233, 'real_attr': 'White_Male'},
#  {'score': 0.7786775526542308, 'real_attr': 'White_Male'},
#  {'score': 0.777875073185488, 'real_attr': 'Asian_Male'},
#  {'score': 0.7773970909407127, 'real_attr': 'White_Female'},
#  {'score': 0.7772568161871966, 'real_attr': 'White_Male'},
#  {'score': 0.7767673192657358, 'real_attr': 'White_Male'},
#  {'score': 0.7767673192657358, 'real_attr': 'White_Male'},
#  {'score': 0.7763507681520708, 'real_attr': 'White_Male'},
#  {'score': 0.7760846433870626, 'real_attr': 'White_Female'},
#  {'score': 0.7757815184172068, 'real_attr': 'White_Male'},
#  {'score': 0.7755787537227001, 'real_attr': 'White_Male'},
#  {'score': 0.7755787537227001, 'real_attr': 'White_Male'},
#  {'score': 0.7754902178162735, 'real_attr': 'White_Male'},
#  {'score': 0.7754902178162735, 'real_attr': 'White_Male'},
#  {'score': 0.7754214113129718, 'real_attr': 'White_Male'},
#  {'score': 0.7751606267219363, 'real_attr': 'White_Male'},
#  {'score': 0.7750866362157274, 'real_attr': 'White_Male'},
#  {'score': 0.7747566247309867, 'real_attr': 'White_Male'},
#  {'score': 0.7746884977037326, 'real_attr': 'White_Male'},
#  {'score': 0.7746842179082193, 'real_attr': 'White_Male'},
#  {'score': 0.7746678587191098, 'real_attr': 'White_Male'},
#  {'score': 0.7743374116677942, 'real_attr': 'White_Male'},
#  {'score': 0.7743374116677942, 'real_attr': 'White_Male'},
#  {'score': 0.7739794909006007, 'real_attr': 'White_Female'},
#  {'score': 0.7739732794759745, 'real_attr': 'White_Male'},
#  {'score': 0.7739406086909347, 'real_attr': 'White_Male'},
#  {'score': 0.7731283785386994, 'real_attr': 'White_Female'},
#  {'score': 0.7727413960721408, 'real_attr': 'White_Male'},
#  {'score': 0.7727331183559045, 'real_attr': 'White_Male'},
#  {'score': 0.7727331183559045, 'real_attr': 'White_Male'},
#  {'score': 0.7727331183559045, 'real_attr': 'White_Male'},
#  {'score': 0.7726388131908669, 'real_attr': 'White_Male'},
#  {'score': 0.7725431056339039, 'real_attr': 'White_Female'},
#  {'score': 0.7724171430599094, 'real_attr': 'White_Male'},
#  {'score': 0.7724006676280093, 'real_attr': 'White_Male'},
#  {'score': 0.772244883819046, 'real_attr': 'White_Male'},
#  {'score': 0.770903233587113, 'real_attr': 'White_Male'},
#  {'score': 0.7706627719415992, 'real_attr': 'White_Female'},
#  {'score': 0.7703333546071007, 'real_attr': 'Asian_Male'},
#  {'score': 0.770272285215128, 'real_attr': 'White_Male'},
#  {'score': 0.7699085604247833, 'real_attr': 'White_Male'},
#  {'score': 0.7698762290724681, 'real_attr': 'White_Male'},
#  {'score': 0.7681994909894764, 'real_attr': 'White_Male'},
#  {'score': 0.7681324940830606, 'real_attr': 'White_Male'},
#  {'score': 0.7681114343167553, 'real_attr': 'White_Male'},
#  {'score': 0.7681114343167553, 'real_attr': 'White_Male'},
#  {'score': 0.768020833632105, 'real_attr': 'White_Male'},
#  {'score': 0.7678455941788903, 'real_attr': 'White_Male'},
#  {'score': 0.7676078486768148, 'real_attr': 'White_Male'},
#  {'score': 0.7676078486768148, 'real_attr': 'White_Male'},
#  {'score': 0.7676078486768148, 'real_attr': 'White_Male'},
#  {'score': 0.7675171107887354, 'real_attr': 'White_Male'},
#  {'score': 0.7674520269839393, 'real_attr': 'White_Female'},
#  {'score': 0.7672785753991548, 'real_attr': 'White_Male'},
#  {'score': 0.7671793288831015, 'real_attr': 'White_Male'},
#  {'score': 0.7671793288831015, 'real_attr': 'White_Male'},
#  {'score': 0.7670698764912623, 'real_attr': 'White_Male'},
#  {'score': 0.7668218034801106, 'real_attr': 'White_Female'},
#  {'score': 0.7663524819492049, 'real_attr': 'White_Male'},
#  {'score': 0.766242759284191, 'real_attr': 'White_Male'},
#  {'score': 0.7661048842572815, 'real_attr': 'White_Male'},
#  {'score': 0.7659924438501029, 'real_attr': 'White_Male'},
#  {'score': 0.7653729006434304, 'real_attr': 'White_Male'},
#  {'score': 0.7650274333782878, 'real_attr': 'White_Male'},
#  {'score': 0.7647389852645344, 'real_attr': 'White_Male'},
#  {'score': 0.7647273854665435, 'real_attr': 'White_Female'},
#  {'score': 0.7644152839968364, 'real_attr': 'White_Male'},
#  {'score': 0.764341706184825, 'real_attr': 'Black_Female'},
#  {'score': 0.7643093483632046, 'real_attr': 'White_Male'},
#  {'score': 0.7638841267345189, 'real_attr': 'White_Male'},
#  {'score': 0.763467038893261, 'real_attr': 'White_Male'},
#  {'score': 0.7634371732250917, 'real_attr': 'White_Male'},
#  {'score': 0.7632527060252863, 'real_attr': 'Black_Male'},
#  {'score': 0.7630033373353025, 'real_attr': 'White_Male'},
#  {'score': 0.7629139159439506, 'real_attr': 'White_Male'},
#  {'score': 0.7628219115927497, 'real_attr': 'White_Male'},
#  {'score': 0.7624025344691691, 'real_attr': 'White_Male'},
#  {'score': 0.7624025344691691, 'real_attr': 'White_Male'},
#  {'score': 0.7623103934972456, 'real_attr': 'White_Male'},
#  {'score': 0.7623103934972456, 'real_attr': 'White_Male'},
#  {'score': 0.7623103934972456, 'real_attr': 'White_Male'},
#  {'score': 0.7622065424977887, 'real_attr': 'White_Female'},
#  {'score': 0.7621802237146647, 'real_attr': 'White_Female'},
#  {'score': 0.7613433015760851, 'real_attr': 'White_Male'},
#  {'score': 0.7613433015760851, 'real_attr': 'White_Male'},
#  {'score': 0.7609068283103936, 'real_attr': 'White_Male'},
#  {'score': 0.7607953465513917, 'real_attr': 'White_Male'},
#  {'score': 0.7605764692743389, 'real_attr': 'White_Female'},
#  {'score': 0.7605722294393993, 'real_attr': 'White_Female'},
#  {'score': 0.7605152496244443, 'real_attr': 'White_Male'},
#  {'score': 0.7603797308215863, 'real_attr': 'White_Male'},
#  {'score': 0.7600132555552559, 'real_attr': 'White_Male'},
#  {'score': 0.75995739430115, 'real_attr': 'White_Male'},
#  {'score': 0.7598646037634815, 'real_attr': 'White_Male'},
#  {'score': 0.7598646037634815, 'real_attr': 'White_Male'},
#  {'score': 0.7598646037634815, 'real_attr': 'White_Male'},
#  {'score': 0.7596891329597678, 'real_attr': 'White_Male'},
#  {'score': 0.7595824354522002, 'real_attr': 'White_Male'},
#  {'score': 0.7594615262496508, 'real_attr': 'White_Female'},
#  {'score': 0.7594583025856833, 'real_attr': 'White_Male'},
#  {'score': 0.7587151915023906, 'real_attr': 'White_Male'},
#  {'score': 0.7578207922947998, 'real_attr': 'White_Male'},
#  {'score': 0.7575432579843714, 'real_attr': 'White_Male'},
#  {'score': 0.7575432579843714, 'real_attr': 'White_Male'},
#  {'score': 0.757296038727746, 'real_attr': 'White_Male'},
#  {'score': 0.7571261867337894, 'real_attr': 'White_Male'},
#  {'score': 0.7571175190180276, 'real_attr': 'White_Male'},
#  {'score': 0.7571175190180276, 'real_attr': 'White_Male'},
#  {'score': 0.7563524650272812, 'real_attr': 'Asian_Male'},
#  {'score': 0.7550641762678678, 'real_attr': 'White_Male'},
#  {'score': 0.7549313138779016, 'real_attr': 'White_Female'},
#  {'score': 0.7549301194290811, 'real_attr': 'White_Male'},
#  {'score': 0.7545413108396346, 'real_attr': 'White_Male'},
#  {'score': 0.7539040378198953, 'real_attr': 'White_Male'},
#  {'score': 0.7536081422128496, 'real_attr': 'Black_Female'},
#  {'score': 0.7534583648600495, 'real_attr': 'White_Male'},
#  {'score': 0.7534463881800852, 'real_attr': 'White_Female'},
#  {'score': 0.7530365575963982, 'real_attr': 'White_Male'},
#  {'score': 0.7524310727469955, 'real_attr': 'White_Female'},
#  {'score': 0.7521852881749936, 'real_attr': 'White_Male'},
#  {'score': 0.7517532240323154, 'real_attr': 'White_Male'},
#  {'score': 0.7517532240323154, 'real_attr': 'White_Male'},
#  {'score': 0.7517532240323154, 'real_attr': 'White_Male'},
#  {'score': 0.7515513102061607, 'real_attr': 'White_Female'},
#  {'score': 0.7514174632459355, 'real_attr': 'White_Male'},
#  {'score': 0.7513049408976251, 'real_attr': 'White_Male'},
#  {'score': 0.7502124431651799, 'real_attr': 'White_Male'},
#  {'score': 0.7496896721110453, 'real_attr': 'White_Male'},
#  {'score': 0.7496695255914376, 'real_attr': 'White_Male'},
#  {'score': 0.7496695255914376, 'real_attr': 'White_Male'},
#  {'score': 0.7495334955968904, 'real_attr': 'White_Male'},
#  {'score': 0.7492433933776028, 'real_attr': 'White_Male'},
#  {'score': 0.7488318025140404, 'real_attr': 'Black_Male'},
#  {'score': 0.7481448752867064, 'real_attr': 'White_Male'},
#  {'score': 0.7480401485162789, 'real_attr': 'White_Male'},
#  {'score': 0.7476121764420618, 'real_attr': 'White_Male'},
#  {'score': 0.7474717805629022, 'real_attr': 'White_Male'},
#  {'score': 0.747391647537419, 'real_attr': 'White_Male'},
#  {'score': 0.746844667806259, 'real_attr': 'White_Male'},
#  {'score': 0.7463905111045734, 'real_attr': 'White_Male'},
#  {'score': 0.7463101514185329, 'real_attr': 'White_Male'},
#  {'score': 0.7462533023957689, 'real_attr': 'White_Male'},
#  {'score': 0.746105305637904, 'real_attr': 'White_Female'},
#  {'score': 0.74543378207902, 'real_attr': 'White_Male'},
#  {'score': 0.7452453513010645, 'real_attr': 'White_Female'},
#  {'score': 0.7450210205532227, 'real_attr': 'White_Male'},
#  {'score': 0.7443379060378043, 'real_attr': 'White_Male'},
#  {'score': 0.7441154953917306, 'real_attr': 'White_Male'},
#  {'score': 0.7439778995718712, 'real_attr': 'White_Female'},
#  {'score': 0.7438050332219199, 'real_attr': 'White_Male'},
#  {'score': 0.743658123098938, 'real_attr': 'White_Male'},
#  {'score': 0.743254002031714, 'real_attr': 'White_Female'},
#  {'score': 0.7425435447288435, 'real_attr': 'White_Male'},
#  {'score': 0.7413310024438964, 'real_attr': 'White_Male'},
#  {'score': 0.7412841834817462, 'real_attr': 'Black_Male'},
#  {'score': 0.7412334633893123, 'real_attr': 'White_Male'},
#  {'score': 0.7410131806627483, 'real_attr': 'White_Male'},
#  {'score': 0.740829583615673, 'real_attr': 'White_Male'},
#  {'score': 0.7402550926056546, 'real_attr': 'White_Male'},
#  {'score': 0.7402550926056546, 'real_attr': 'White_Male'},
#  {'score': 0.7401120268596082, 'real_attr': 'White_Male'},
#  {'score': 0.7398911244786077, 'real_attr': 'White_Male'},
#  {'score': 0.7391396200621592, 'real_attr': 'White_Male'},
#  {'score': 0.7390451246108429, 'real_attr': 'Asian_Male'},
#  {'score': 0.7390451246108429, 'real_attr': 'Asian_Male'},
#  {'score': 0.7387887393426783, 'real_attr': 'White_Male'},
#  {'score': 0.7386658755585196, 'real_attr': 'White_Male'},
#  {'score': 0.7376149137578106, 'real_attr': 'White_Male'},
#  {'score': 0.7374524334053996, 'real_attr': 'White_Male'},
#  {'score': 0.7374342871948089, 'real_attr': 'White_Male'},
#  {'score': 0.7373638691350974, 'real_attr': 'White_Female'},
#  {'score': 0.7372247979392559, 'real_attr': 'White_Female'},
#  {'score': 0.7370677703586396, 'real_attr': 'White_Male'},
#  {'score': 0.7369691941063813, 'real_attr': 'White_Male'},
#  {'score': 0.7365903518382817, 'real_attr': 'White_Female'},
#  {'score': 0.7356408459772827, 'real_attr': 'White_Male'},
#  {'score': 0.7352993507562259, 'real_attr': 'Asian_Male'},
#  {'score': 0.7352727243748695, 'real_attr': 'White_Male'},
#  {'score': 0.7351492999416767, 'real_attr': 'Asian_Male'},
#  {'score': 0.7349794554086428, 'real_attr': 'White_Female'},
#  {'score': 0.734944740332639, 'real_attr': 'White_Male'},
#  {'score': 0.7348215686980204, 'real_attr': 'White_Male'},
#  {'score': 0.7345038535921807, 'real_attr': 'White_Male'},
#  {'score': 0.7345038535921807, 'real_attr': 'White_Male'},
#  {'score': 0.7337958506772143, 'real_attr': 'White_Female'},
#  {'score': 0.7334642964267681, 'real_attr': 'White_Male'},
#  {'score': 0.7332280650740249, 'real_attr': 'White_Female'},
#  {'score': 0.7331623058997705, 'real_attr': 'White_Male'},
#  {'score': 0.7328748877685596, 'real_attr': 'White_Male'},
#  {'score': 0.7326145074428446, 'real_attr': 'White_Male'},
#  {'score': 0.732219116769082, 'real_attr': 'Asian_Male'},
#  {'score': 0.7317892707308663, 'real_attr': 'White_Male'},
#  {'score': 0.7313614902585289, 'real_attr': 'White_Female'},
#  {'score': 0.7313614902585289, 'real_attr': 'White_Female'},
#  {'score': 0.7313178215969939, 'real_attr': 'White_Male'},
#  {'score': 0.7313178215969939, 'real_attr': 'White_Male'},
#  {'score': 0.7313178215969939, 'real_attr': 'White_Male'},
#  {'score': 0.7311974172126776, 'real_attr': 'White_Male'},
#  {'score': 0.730825372147506, 'real_attr': 'White_Male'},
#  {'score': 0.7307039588254944, 'real_attr': 'White_Female'},
#  {'score': 0.7302333968590182, 'real_attr': 'White_Male'},
#  {'score': 0.73007162868451, 'real_attr': 'White_Male'},
#  {'score': 0.7295145236627049, 'real_attr': 'White_Male'},
#  {'score': 0.7295145236627049, 'real_attr': 'White_Male'},
#  {'score': 0.7295145236627049, 'real_attr': 'White_Male'},
#  {'score': 0.7295145236627049, 'real_attr': 'White_Male'},
#  {'score': 0.7291920131025577, 'real_attr': 'Black_Male'},
#  {'score': 0.7291410121675226, 'real_attr': 'White_Male'},
#  {'score': 0.729024586614669, 'real_attr': 'White_Male'},
#  {'score': 0.7289783645705349, 'real_attr': 'Black_Female'},
#  {'score': 0.7287261162079306, 'real_attr': 'White_Male'},
#  {'score': 0.7285920214933581, 'real_attr': 'White_Male'},
#  {'score': 0.7285836510127712, 'real_attr': 'White_Male'},
#  {'score': 0.7285331937685613, 'real_attr': 'Black_Male'},
#  {'score': 0.7280844265010336, 'real_attr': 'White_Male'},
#  {'score': 0.7280185345978941, 'real_attr': 'White_Male'},
#  {'score': 0.727851591372003, 'real_attr': 'Asian_Male'},
#  {'score': 0.7276869628237775, 'real_attr': 'White_Male'},
#  {'score': 0.7274593883305631, 'real_attr': 'White_Male'},
#  {'score': 0.7273457565132839, 'real_attr': 'White_Female'},
#  {'score': 0.7273118709937682, 'real_attr': 'White_Male'},
#  {'score': 0.7272364107773044, 'real_attr': 'White_Male'},
#  {'score': 0.7269042431915214, 'real_attr': 'White_Male'},
#  {'score': 0.7267512019381134, 'real_attr': 'White_Male'},
#  {'score': 0.7267512019381134, 'real_attr': 'White_Male'},
#  {'score': 0.7263002998925453, 'real_attr': 'White_Male'},
#  {'score': 0.726067972465213, 'real_attr': 'White_Male'},
#  {'score': 0.726067972465213, 'real_attr': 'White_Male'},
#  {'score': 0.7257008741283408, 'real_attr': 'White_Male'},
#  {'score': 0.7253802422038681, 'real_attr': 'White_Male'},
#  {'score': 0.7247910519108773, 'real_attr': 'White_Male'},
#  {'score': 0.7247375107836413, 'real_attr': 'White_Male'},
#  {'score': 0.7243274933110674, 'real_attr': 'White_Male'},
#  {'score': 0.7242259277040952, 'real_attr': 'White_Male'},
#  {'score': 0.7241735559915026, 'real_attr': 'White_Male'},
#  {'score': 0.7237630186643865, 'real_attr': 'White_Male'},
#  {'score': 0.7237630186643865, 'real_attr': 'White_Male'},
#  {'score': 0.7231182071328108, 'real_attr': 'Asian_Male'},
#  {'score': 0.7229405306272415, 'real_attr': 'White_Male'},
#  {'score': 0.7229193817525693, 'real_attr': 'White_Female'},
#  {'score': 0.7224019309663223, 'real_attr': 'White_Male'},
#  {'score': 0.7213857702095761, 'real_attr': 'White_Male'},
#  {'score': 0.7210751981901621, 'real_attr': 'White_Male'},
#  {'score': 0.7209634134889471, 'real_attr': 'White_Male'},
#  {'score': 0.7206850064827843, 'real_attr': 'White_Male'},
#  {'score': 0.720271282487475, 'real_attr': 'White_Male'},
#  {'score': 0.7199319937728558, 'real_attr': 'White_Male'},
#  {'score': 0.7198899080024522, 'real_attr': 'White_Male'},
#  {'score': 0.7198293610955692, 'real_attr': 'White_Male'},
#  {'score': 0.7197026859612649, 'real_attr': 'White_Male'},
#  {'score': 0.7193293844544603, 'real_attr': 'White_Male'},
#  {'score': 0.7191268327228003, 'real_attr': 'White_Male'},
#  {'score': 0.7182587416064026, 'real_attr': 'White_Male'},
#  {'score': 0.7180224532841729, 'real_attr': 'White_Male'},
#  {'score': 0.7179365016880878, 'real_attr': 'White_Male'},
#  {'score': 0.7177174108709949, 'real_attr': 'White_Female'},
#  {'score': 0.7176559999689154, 'real_attr': 'White_Male'},
#  {'score': 0.7174501044173499, 'real_attr': 'White_Male'},
#  {'score': 0.7173258875857949, 'real_attr': 'White_Male'},
#  {'score': 0.7167156302974838, 'real_attr': 'White_Male'},
#  {'score': 0.7161885889133769, 'real_attr': 'White_Male'},
#  {'score': 0.7161550850815569, 'real_attr': 'White_Male'},
#  {'score': 0.7155258537387144, 'real_attr': 'Black_Female'},
#  {'score': 0.7152449690429282, 'real_attr': 'White_Female'},
#  {'score': 0.715223265462295, 'real_attr': 'White_Male'},
#  {'score': 0.7151010903598409, 'real_attr': 'White_Male'},
#  {'score': 0.714905182435431, 'real_attr': 'White_Male'},
#  {'score': 0.7147154588990104, 'real_attr': 'White_Male'},
#  {'score': 0.7142963980772069, 'real_attr': 'White_Male'},
#  {'score': 0.7141332875865132, 'real_attr': 'White_Male'},
#  {'score': 0.713910113165868, 'real_attr': 'White_Male'},
#  {'score': 0.7134559000691992, 'real_attr': 'White_Male'},
#  {'score': 0.7127808491530317, 'real_attr': 'White_Female'},
#  {'score': 0.7126149086366227, 'real_attr': 'White_Male'},
#  {'score': 0.7125107405243122, 'real_attr': 'White_Male'},
#  {'score': 0.7120359856765144, 'real_attr': 'White_Male'},
#  {'score': 0.7120359856765144, 'real_attr': 'White_Male'},
#  {'score': 0.7115435015761215, 'real_attr': 'White_Male'},
#  {'score': 0.7098523914042607, 'real_attr': 'White_Male'},
#  {'score': 0.7092798934372159, 'real_attr': 'White_Male'},
#  {'score': 0.7090874540275803, 'real_attr': 'White_Male'},
#  {'score': 0.7089669597326221, 'real_attr': 'White_Male'},
#  {'score': 0.7085433945152602, 'real_attr': 'White_Male'},
#  {'score': 0.7079596309399642, 'real_attr': 'White_Male'},
#  {'score': 0.7069152034628875, 'real_attr': 'White_Male'},
#  {'score': 0.7060625722761562, 'real_attr': 'White_Male'},
#  {'score': 0.7060625722761562, 'real_attr': 'White_Male'},
#  {'score': 0.7060625722761562, 'real_attr': 'White_Male'},
#  {'score': 0.7056981541544556, 'real_attr': 'Asian_Male'},
#  {'score': 0.7055640966807888, 'real_attr': 'White_Male'},
#  {'score': 0.7040801618425239, 'real_attr': 'White_Female'},
#  {'score': 0.7040236326532072, 'real_attr': 'White_Male'},
#  {'score': 0.7040236326532072, 'real_attr': 'White_Male'},
#  {'score': 0.7038429671400132, 'real_attr': 'Asian_Male'},
#  {'score': 0.7034323904242892, 'real_attr': 'White_Female'},
#  {'score': 0.7032731337389774, 'real_attr': 'White_Male'},
#  {'score': 0.7031571515558758, 'real_attr': 'White_Male'},
#  {'score': 0.7026071490900266, 'real_attr': 'White_Female'},
#  {'score': 0.7020822668161941, 'real_attr': 'White_Male'},
#  {'score': 0.701937055890746, 'real_attr': 'White_Male'},
#  {'score': 0.7016475212676089, 'real_attr': 'White_Male'},
#  {'score': 0.7014717825111564, 'real_attr': 'White_Male'},
#  {'score': 0.7009659854389538, 'real_attr': 'White_Male'},
#  {'score': 0.700610377982, 'real_attr': 'White_Male'},
#  {'score': 0.7005036873440733, 'real_attr': 'White_Male'},
#  {'score': 0.7002503860725359, 'real_attr': 'Asian_Female'},
#  {'score': 0.7000515283506168, 'real_attr': 'White_Male'},
#  {'score': 0.6999884803680217, 'real_attr': 'White_Male'},
#  {'score': 0.6995794996886625, 'real_attr': 'White_Female'},
#  {'score': 0.6995130880373498, 'real_attr': 'White_Male'},
#  {'score': 0.6988933866332748, 'real_attr': 'White_Male'},
#  {'score': 0.6983348609711041, 'real_attr': 'White_Female'},
#  {'score': 0.6982144548482401, 'real_attr': 'White_Male'},
#  {'score': 0.6978310303776771, 'real_attr': 'White_Male'},
#  {'score': 0.6978310303776771, 'real_attr': 'White_Male'},
#  {'score': 0.6977420863963065, 'real_attr': 'White_Male'},
#  {'score': 0.6976741409600663, 'real_attr': 'White_Male'},
#  {'score': 0.6975212567423706, 'real_attr': 'White_Male'},
#  {'score': 0.6973480025107338, 'real_attr': 'White_Male'},
#  {'score': 0.6972043992854577, 'real_attr': 'White_Male'},
#  {'score': 0.697077914541907, 'real_attr': 'White_Male'},
#  {'score': 0.6968617547347113, 'real_attr': 'White_Female'},
#  {'score': 0.6966117063726748, 'real_attr': 'Black_Female'},
#  {'score': 0.6965984889778473, 'real_attr': 'White_Male'},
#  {'score': 0.6965249607842906, 'real_attr': 'White_Male'},
#  {'score': 0.6963514900146439, 'real_attr': 'White_Male'},
#  {'score': 0.6959612442763448, 'real_attr': 'White_Male'},
#  {'score': 0.6958436401338397, 'real_attr': 'White_Male'},
#  {'score': 0.6949756751470513, 'real_attr': 'Asian_Male'},
#  {'score': 0.6948830654872274, 'real_attr': 'White_Male'},
#  {'score': 0.6948642136060542, 'real_attr': 'White_Male'},
#  {'score': 0.694773906322735, 'real_attr': 'White_Male'},
#  {'score': 0.6945299341119242, 'real_attr': 'White_Female'},
#  {'score': 0.694393726451624, 'real_attr': 'White_Male'},
#  {'score': 0.6939920602754598, 'real_attr': 'White_Male'},
#  {'score': 0.6939019064501217, 'real_attr': 'White_Male'},
#  {'score': 0.6939019064501217, 'real_attr': 'White_Male'},
#  {'score': 0.6937292425892487, 'real_attr': 'Black_Male'},
#  {'score': 0.6936721124606409, 'real_attr': 'White_Female'},
#  {'score': 0.6936721124606409, 'real_attr': 'White_Female'},
#  {'score': 0.6929090741272169, 'real_attr': 'White_Male'},
#  {'score': 0.6926310262247365, 'real_attr': 'White_Male'},
#  {'score': 0.6925408751654389, 'real_attr': 'White_Male'},
#  {'score': 0.692043737444758, 'real_attr': 'White_Male'},
#  {'score': 0.6913772580862196, 'real_attr': 'White_Male'},
#  {'score': 0.6908447157667965, 'real_attr': 'White_Male'},
#  {'score': 0.690735858614319, 'real_attr': 'White_Female'},
#  {'score': 0.6906894058807618, 'real_attr': 'White_Male'},
#  {'score': 0.6904440651281204, 'real_attr': 'White_Male'},
#  {'score': 0.6904440651281204, 'real_attr': 'White_Male'},
#  {'score': 0.6904440651281204, 'real_attr': 'White_Male'},
#  {'score': 0.6902289821795488, 'real_attr': 'White_Male'},
#  {'score': 0.6900794657833813, 'real_attr': 'White_Male'},
#  {'score': 0.6887188443584564, 'real_attr': 'Asian_Male'},
#  {'score': 0.6883585303614095, 'real_attr': 'White_Male'},
#  {'score': 0.6879681798880053, 'real_attr': 'White_Male'},
#  {'score': 0.6877526708229518, 'real_attr': 'White_Male'},
#  {'score': 0.6877173046956335, 'real_attr': 'White_Male'},
#  {'score': 0.6876723067912807, 'real_attr': 'Asian_Male'},
#  {'score': 0.6874020355069599, 'real_attr': 'White_Male'},
#  {'score': 0.6870401227293677, 'real_attr': 'White_Male'},
#  {'score': 0.6869948054377669, 'real_attr': 'White_Male'},
#  {'score': 0.6866977515944713, 'real_attr': 'White_Male'},
#  {'score': 0.6862860717309817, 'real_attr': 'White_Male'},
#  {'score': 0.6861626792460407, 'real_attr': 'White_Female'},
#  {'score': 0.6860902853514028, 'real_attr': 'White_Male'},
#  {'score': 0.6857289963666694, 'real_attr': 'White_Male'},
#  {'score': 0.6853211027468789, 'real_attr': 'White_Male'},
#  {'score': 0.6852195050760754, 'real_attr': 'White_Male'},
#  {'score': 0.6851647906570466, 'real_attr': 'White_Male'},
#  {'score': 0.6851647906570466, 'real_attr': 'White_Male'},
#  {'score': 0.6842213926148981, 'real_attr': 'White_Male'},
#  {'score': 0.6839873900126917, 'real_attr': 'White_Male'},
#  {'score': 0.68397164190734, 'real_attr': 'Asian_Female'},
#  {'score': 0.6837606043879872, 'real_attr': 'White_Female'},
#  {'score': 0.6834497434639603, 'real_attr': 'White_Male'},
#  {'score': 0.6833427628896673, 'real_attr': 'White_Male'},
#  {'score': 0.6827713186178522, 'real_attr': 'White_Male'},
#  {'score': 0.6817028282247627, 'real_attr': 'White_Male'},
#  {'score': 0.6815008215224788, 'real_attr': 'Black_Male'},
#  {'score': 0.6814746660978271, 'real_attr': 'White_Male'},
#  {'score': 0.6813080007340043, 'real_attr': 'White_Male'},
#  {'score': 0.6810895019608862, 'real_attr': 'White_Male'},
#  {'score': 0.6805518866002415, 'real_attr': 'White_Male'},
#  {'score': 0.680038964326079, 'real_attr': 'White_Male'},
#  {'score': 0.6796821043572803, 'real_attr': 'White_Male'},
#  {'score': 0.6790433202740828, 'real_attr': 'White_Male'},
#  {'score': 0.678538232818066, 'real_attr': 'White_Male'},
#  {'score': 0.678427286784784, 'real_attr': 'White_Male'},
#  {'score': 0.6781280442027271, 'real_attr': 'White_Male'},
#  {'score': 0.6780348260040076, 'real_attr': 'White_Male'},
#  {'score': 0.6776112323967808, 'real_attr': 'White_Male'},
#  {'score': 0.6775832372882438, 'real_attr': 'White_Male'},
#  {'score': 0.6764357082255072, 'real_attr': 'White_Male'},
#  {'score': 0.6759004050217275, 'real_attr': 'White_Male'},
#  {'score': 0.6757661768326559, 'real_attr': 'White_Male'},
#  {'score': 0.6754030697738594, 'real_attr': 'White_Male'},
#  {'score': 0.6742447724850231, 'real_attr': 'White_Male'},
#  {'score': 0.6742365339041355, 'real_attr': 'White_Male'},
#  {'score': 0.6741217666571852, 'real_attr': 'White_Male'},
#  {'score': 0.6738904616849816, 'real_attr': 'White_Male'},
#  {'score': 0.6737747508181813, 'real_attr': 'White_Female'},
#  {'score': 0.6736542415926842, 'real_attr': 'White_Male'},
#  {'score': 0.6729378730731366, 'real_attr': 'White_Female'},
#  {'score': 0.6728638829827228, 'real_attr': 'White_Male'},
#  {'score': 0.6727001104164644, 'real_attr': 'White_Male'},
#  {'score': 0.6727001104164644, 'real_attr': 'White_Male'},
#  {'score': 0.6727001104164644, 'real_attr': 'White_Male'},
#  {'score': 0.6726423765338602, 'real_attr': 'White_Male'},
#  {'score': 0.6725405246220957, 'real_attr': 'White_Male'},
#  {'score': 0.6720777814821877, 'real_attr': 'White_Male'},
#  {'score': 0.6719557330778486, 'real_attr': 'Black_Female'},
#  {'score': 0.6718816291373003, 'real_attr': 'Black_Male'},
#  {'score': 0.6715774306138482, 'real_attr': 'White_Male'},
#  {'score': 0.6715774306138482, 'real_attr': 'White_Male'},
#  {'score': 0.6714133285233019, 'real_attr': 'White_Male'},
#  {'score': 0.6713554785501219, 'real_attr': 'White_Male'},
#  {'score': 0.6711713198412719, 'real_attr': 'White_Male'},
#  {'score': 0.6709378817090053, 'real_attr': 'White_Male'},
#  {'score': 0.6704594224027133, 'real_attr': 'Other_Male'},
#  {'score': 0.6704416054626866, 'real_attr': 'White_Female'},
#  {'score': 0.6702986934704109, 'real_attr': 'White_Male'},
#  {'score': 0.6700972897588836, 'real_attr': 'White_Male'},
#  {'score': 0.6694446083222384, 'real_attr': 'White_Female'},
#  {'score': 0.6694418123550744, 'real_attr': 'White_Male'},
#  {'score': 0.6694418123550744, 'real_attr': 'White_Male'},
#  {'score': 0.6690229826744984, 'real_attr': 'White_Male'},
#  {'score': 0.6687642092088613, 'real_attr': 'White_Male'},
#  {'score': 0.6686515371452136, 'real_attr': 'White_Male'},
#  {'score': 0.6676263728795185, 'real_attr': 'White_Male'},
#  {'score': 0.667413535971349, 'real_attr': 'White_Male'},
#  {'score': 0.6662931451993198, 'real_attr': 'White_Male'},
#  {'score': 0.6662931451993198, 'real_attr': 'White_Male'},
#  {'score': 0.6662608589455504, 'real_attr': 'White_Male'},
#  {'score': 0.6662348418974845, 'real_attr': 'White_Male'},
#  {'score': 0.6662012349889705, 'real_attr': 'Black_Female'},
#  {'score': 0.6657883571718723, 'real_attr': 'White_Male'},
#  {'score': 0.6657778687148275, 'real_attr': 'White_Male'},
#  {'score': 0.6656646886682835, 'real_attr': 'White_Male'},
#  {'score': 0.665253388777026, 'real_attr': 'NativeAm_Male'},
#  {'score': 0.6652291083576001, 'real_attr': 'White_Female'},
#  {'score': 0.6651955695288978, 'real_attr': 'White_Male'},
#  {'score': 0.6649937184738586, 'real_attr': 'White_Male'},
#  {'score': 0.6649458039031224, 'real_attr': 'White_Male'},
#  {'score': 0.6646319052858076, 'real_attr': 'White_Male'},
#  {'score': 0.6639321879906811, 'real_attr': 'White_Male'},
#  {'score': 0.6639074075935005, 'real_attr': 'White_Female'},
#  {'score': 0.6638841983330249, 'real_attr': 'White_Male'},
#  {'score': 0.6630030175360643, 'real_attr': 'White_Male'},
#  {'score': 0.662950434673104, 'real_attr': 'White_Male'},
#  {'score': 0.6629036173051611, 'real_attr': 'Asian_Male'},
#  {'score': 0.662872510460246, 'real_attr': 'White_Male'},
#  {'score': 0.6618485201991541, 'real_attr': 'White_Male'},
#  {'score': 0.6618379708990728, 'real_attr': 'White_Male'},
#  {'score': 0.6601951456284474, 'real_attr': 'White_Male'},
#  {'score': 0.65999114331565, 'real_attr': 'White_Male'},
#  {'score': 0.659876840231763, 'real_attr': 'Asian_Female'},
#  {'score': 0.6591897766266431, 'real_attr': 'White_Male'},
#  {'score': 0.6586685574250454, 'real_attr': 'White_Male'},
#  {'score': 0.6577614730398655, 'real_attr': 'White_Male'},
#  {'score': 0.6576765724151646, 'real_attr': 'Black_Male'},
#  {'score': 0.6573000251257315, 'real_attr': 'White_Female'},
#  {'score': 0.6572249794766205, 'real_attr': 'White_Male'},
#  {'score': 0.6564500861382665, 'real_attr': 'White_Male'},
#  {'score': 0.6563353778490967, 'real_attr': 'White_Male'},
#  {'score': 0.6563353778490967, 'real_attr': 'White_Male'},
#  {'score': 0.6561469501553249, 'real_attr': 'White_Female'},
#  {'score': 0.6547577602955151, 'real_attr': 'White_Male'},
#  {'score': 0.6543087133617048, 'real_attr': 'White_Male'},
#  {'score': 0.6537706682111426, 'real_attr': 'White_Male'},
#  {'score': 0.653463554899274, 'real_attr': 'White_Male'},
#  {'score': 0.6532950744698988, 'real_attr': 'White_Male'},
#  {'score': 0.6529492494799191, 'real_attr': 'Black_Male'},
#  {'score': 0.6526549002054912, 'real_attr': 'White_Male'},
#  {'score': 0.6519119732245701, 'real_attr': 'White_Male'},
#  {'score': 0.6517225713287669, 'real_attr': 'White_Male'},
#  {'score': 0.6515893297722077, 'real_attr': 'White_Male'},
#  {'score': 0.6513877465724232, 'real_attr': 'White_Male'},
#  {'score': 0.6508623329628589, 'real_attr': 'White_Male'},
#  {'score': 0.6506180849726392, 'real_attr': 'White_Male'},
#  {'score': 0.6504878080777818, 'real_attr': 'White_Female'},
#  {'score': 0.6503578661401516, 'real_attr': 'White_Male'},
#  {'score': 0.6503578661401516, 'real_attr': 'White_Male'},
#  {'score': 0.6501563833818595, 'real_attr': 'White_Male'},
#  {'score': 0.6501563833818595, 'real_attr': 'White_Male'},
#  {'score': 0.6501350660832915, 'real_attr': 'White_Male'},
#  {'score': 0.6500886352247739, 'real_attr': 'Asian_Female'},
#  {'score': 0.649891875131429, 'real_attr': 'White_Male'},
#  {'score': 0.6497151763956333, 'real_attr': 'White_Male'},
#  {'score': 0.6495810181008735, 'real_attr': 'White_Male'},
#  {'score': 0.6492844466982979, 'real_attr': 'White_Male'},
#  {'score': 0.6492474929861068, 'real_attr': 'White_Male'},
#  {'score': 0.6491343931971254, 'real_attr': 'White_Female'},
#  {'score': 0.6488534736071668, 'real_attr': 'White_Male'},
#  {'score': 0.6487006059536338, 'real_attr': 'White_Male'},
#  {'score': 0.6483852623267117, 'real_attr': 'White_Male'},
#  {'score': 0.6482102209055719, 'real_attr': 'White_Male'},
#  {'score': 0.6477516656174372, 'real_attr': 'White_Male'},
#  {'score': 0.6473774676435885, 'real_attr': 'White_Male'},
#  {'score': 0.6473774676435885, 'real_attr': 'White_Male'},
#  {'score': 0.6471536570813575, 'real_attr': 'Asian_Male'},
#  {'score': 0.6470853615635026, 'real_attr': 'White_Male'},
#  {'score': 0.6469121469732972, 'real_attr': 'White_Male'},
#  {'score': 0.6468776985001622, 'real_attr': 'White_Male'},
#  {'score': 0.6468776985001622, 'real_attr': 'White_Male'},
#  {'score': 0.6467077472471525, 'real_attr': 'White_Male'},
#  {'score': 0.6467077472471525, 'real_attr': 'White_Male'},
#  {'score': 0.6466478367912241, 'real_attr': 'White_Male'},
#  {'score': 0.6460619994882277, 'real_attr': 'White_Male'},
#  {'score': 0.6459590002997927, 'real_attr': 'White_Male'},
#  {'score': 0.6451777109575398, 'real_attr': 'White_Male'},
#  ...]

# %%
import json
f = open('incomedatalist.json','w')
json.dump(incomedata,f)
f.close()

# %%
set([i['real_attr'] for i in incomedata])
# Out:
# {'Asian_Female',
#  'Asian_Male',
#  'Black_Female',
#  'Black_Male',
#  'NativeAm_Female',
#  'NativeAm_Male',
#  'Other_Female',
#  'Other_Male',
#  'White_Female',
#  'White_Male'}
