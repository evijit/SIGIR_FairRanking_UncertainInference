# %%
import os
import json
import pickle
import numpy as np
import matplotlib.pyplot as plt
import sklearn 
import nltk
import pprint
import pdb
import re
import traceback

resume_dir = '/net/data/hiring-sites/indeed/resumes/'
data_dir   = '/net/data/hiring-sites/indeed/data/'

# %%
'''
Creating embeddings 

Features
-  Full Name : Use a char-embedding approach [race/gender]
-  additionalInfo : (Glove embeddings of each word [mean]/[max]) / Bert encoder -> [sentence level representation] 
-  eductaion : One-hot-encoding of tuples with (degree, school)
-  headline : same tech as additionalInfo
-  lastUpdated : store as unix representation of date
-  workExperience : Tuples of company, description, customized date range, current
-  

'''
# Out:
# '\nCreating embeddings \n\nFeatures\n-  Full Name : Use a char-embedding approach [race/gender]\n-  additionalInfo : (Glove embeddings of each word [mean]/[max]) / Bert encoder -> [sentence level representation] \n-  eductaion : One-hot-encoding of tuples with (degree, school)\n-  headline : same tech as additionalInfo\n-  lastUpdated : store as unix representation of date\n-  workExperience : Tuples of company, description, customized date range, current\n-  \n\n'

# %%
import sys; sys.path.append('FairRanking/')
from gender_classifier import *
from ethnicity_classifier import *

gender_dict1 = {}
gender_dict1['seed']       = 100
gender_dict1['classifier'] = 'gender'
gender_dict1['middle_name']= 'no'

ethnicity_dict1 = {}
ethnicity_dict1['seed']       = 100
ethnicity_dict1['classifier'] = 'ethnicity'
ethnicity_dict1['middle_name']= 'no'

gender_dict2 = {}
gender_dict2['seed']       = 11747
gender_dict2['classifier'] = 'gender'
gender_dict2['middle_name']= 'no'

ethnicity_dict2 = {}
ethnicity_dict2['seed']       = 11747
ethnicity_dict2['classifier'] = 'ethnicity'
ethnicity_dict2['middle_name']= 'no'

gender_dict3 = {}
gender_dict3['seed']       = 42
gender_dict3['classifier'] = 'gender'
gender_dict3['middle_name']= 'no'

ethnicity_dict3 = {}
ethnicity_dict3['seed']       = 42
ethnicity_dict3['classifier'] = 'ethnicity'
ethnicity_dict3['middle_name']= 'no'

from collections import defaultdict as ddict

ethnic_map_dict = {}
ethnic_map_dict['Latino']     =    'Hispanic'
ethnic_map_dict['White']      =    'Caucasian'
ethnic_map_dict['Asian']      =    'Asian'
ethnic_map_dict['Black']      =    'African-American'
ethnic_map_dict['NativeAm']   =    'Native American'

gender_map_dict = {}
gender_map_dict['M'] = 'Male'
gender_map_dict['F'] = 'Female'


def maj_vote(name):
    eth_vals = ddict(int)
    for edict in [ethnicity_dict1, ethnicity_dict2, ethnicity_dict3]:
        v = call_ethnicity_inference(name, edict)
        eth_vals[v]+=1
    race  = max(eth_vals, key=eth_vals.get)

    gen_vals = ddict(int)
    for gdict in [gender_dict1, gender_dict2, gender_dict3]:
        v = call_gender_inference(name, gdict)
        gen_vals[v]+=1

    gender = max(gen_vals, key=gen_vals.get)    
    return ethnic_map_dict[race]+'_'+gender_map_dict[gender]
# Out:
# 7722297it [01:01, 125536.72it/s]
# 0it [00:00, ?it/s]
# {'M': 0, 'F': 1}
# 7722297it [01:00, 126688.38it/s]

# %%
resume_list = os.listdir(resume_dir) 
cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')

def preprocess_text(text):
	cleantext = re.sub(cleanr, '', text)
	return cleantext

resume_dict = {}
resume_dict['queryname'] =   []
resume_dict['name']  =   []
resume_dict['race+gender']    =   []
resume_dict['rank']      =   []

for count, resume_page in enumerate(resume_list):
    resume_arr = open(resume_dir+resume_page).read().split('\n')
    rank = 1
    for resume_str in resume_arr:
        if resume_str == '':
            continue
        resumes = json.loads(preprocess_text(resume_str))
        for resume in resumes:
            try:
                name = resume['displayFullName']
                race_gender = maj_vote(re.sub(r'[^a-z ]+','',name.lower()).strip())
                
                resume_dict['queryname'].append(resume_page)
                resume_dict['name'].append(name)
                resume_dict['race+gender'].append(race_gender)
                resume_dict['rank'].append(rank)
                print(name, race_gender)
                rank += 1
            except Exception as e:
                print(e)
                pdb.set_trace()
                continue

    print('Done for count = {}'.format(count), end ='\r')
# Out:
# Calculated padded input size per channel: (3). Kernel size: (4). Kernel size can't be greater than actual input size
# > <ipython-input-6-c11f4e48ffac>(21)<module>()
# -> for resume in resumes:
# (Pdb) print(name)
# N B
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-6-c11f4e48ffac> in <module>
#      19             continue
#      20         resumes = json.loads(preprocess_text(resume_str))
# ---> 21         for resume in resumes:
#      22             try:
#      23                 name = resume['displayFullName']
#
# <ipython-input-6-c11f4e48ffac> in <module>
#      19             continue
#      20         resumes = json.loads(preprocess_text(resume_str))
# ---> 21         for resume in resumes:
#      22             try:
#      23                 name = resume['displayFullName']
#
# ~/anaconda3/envs/py37/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~/anaconda3/envs/py37/lib/python3.7/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
resume_dict = {}
resume_dict['queryname'] =   []
resume_dict['fullname']  =   []
resume_dict['gender']    =   []
resume_dict['race']      =   []
resume_dict['rank']      =   []


for count, resume_page in enumerate(resume_list):
    if count >3:
        break
    resume_arr = open(resume_dir+resume_page).read().split('\n')
    rank       = 1
    for resume_str in resume_arr:
        try:
            print('\n\n')
            if resume_str =='':
                continue
            resumes = json.loads(preprocess_text(resume_str))
            for resume in resumes:
                name = resume['displayFullName']
                
        except Exception as e:
              print(e)
#             traceback.print_exc()
# Out:
# 2
#
#
#
# David Hurford
# Veronica Flores
# David Hurford
# Chela White-Ramsey
# Kimberly Patrick
# Byron Morgan
# Charlotte Hayes
# Charlotte Jeffreys
# Mark Sarisky
# Desareé Williams
# Tj Shelton
# Mike Rathbun
# Helynn Nelson
# Tasha Robles
# Kim Wiltshire
# Frank Acker
# Suresh Peram
# Kimberly Williams
#
#
#
# 6
#
#
#
# Saswati Upadhyaya
# Lori Kline
# Latasha Alexander, MBA
# Rene D. Joesph
# Steven Sohanaki
# Rohan Mehta
# Rani Kaliappan
# R. Vera
# R. Vera
# Ashley Ulbricht
# Parvathy Kalyani Dhulipalla
# Morgan Dearing
# Priyanka Uppal
# Vanessa Hoenninger
# Tom Marks
# Katelijne Van Cauteren
# Matt Brown
# Derrick Lattimore
# Chivas Watson
# Robert La Rocca
# Michele Snethkamp
# Sherroll Reese
# Graham Pionkowski
# Aaron Mayberry
# Evelyn Burrows
# James Hatheway
# Vaishnavi Gopalan
# Zen Van Loan
# George Trail
# Lee Howard
# Priyanka Das
# N B
# Keya Jackson
# Brian Conlin
# Kassandra Ward
# Natalie Tisdale
#
#
#
# Robyn Wright
# Muhammad Bangash
# Laura Flores
# Silvia Londono
# Laredo Ginn
# Radha Sree
# David Keils
# Dave Wiersma
# Marty James
# Daniel Needles
# Steven Busby
# John Harvey
# Jose Cajigas
# Scott Atkins
# Jesika Petruck
# Nicole Eldridge
# Matt Ellis
# Job Seeker
# Brady McElroy
# Nicholas Schenk
# Mariah Gray
# Casey Chevalier
# Brian Conlin
# Kassandra Ward
# Thomas Rackley
# Cissy Lux
# Natalie Tisdale
# Jeffrey Ray
# Kathleen Dunn
# Anjanaa Parasuraman
# Amy Morehart
# Mike Ruhlin
# Nathaniel Mauer
# Kacey Aumack
# Dorian York
# Zachary Ellis
# Ryan White
# Brittnye S
# De Hansen
# Alex Escobar
# Arunraj Nair
# Leah Hudson
# Nida Sellers
# Anne Bleier
# Laura Gonzalez
# Laura Davis
# Jordan Johnson
# Matthew Jones
# Jessica M
# K Atie U
#
#
#
# 3
#
#
#
# Ella Malone
# Emma Coll
# Chantel L. Neill
# Katrina Smith
# Julia Johnston- Manuel
# Scott Newman
# Gina Briones
# Allen Latour
# Colette Resnikoff
# Kimberly Banse
# William Simons
# Cameron Owens
# Jerry DeVreugd
# Rayford Williams
# Aedri Michael
# LeeAnn Friemoth
# Neal Wood
# Debra West-Span
# Jennifer Walsh
# Randolph Allen
# Gaius Cameron
# Shivonne DeAngelo
# Robert Fowler
# Autumn Walsh
# Miranda Saldivar
# Michael Glass
# Christopher Calistri
# Karen (Karme) Fitzpatrick
# Lauren Nelson
# Crystal Ellis
# Denise Eldred
# Joel Marquez
# Debora Cooper
# Pam Wareham
# Arthur Taylor
# Kasandra Turner
# Dollar Phillips
# Clay Norman, PMP
# Katrina Smith
# Kiz Tullous
# Mileta Timmons
# Joseph Launey
# Joseph Slusarski
# Alix Keller
# Teddy Allen
# Harold Byrd
# Jason Greene
# David Minor
# Linda Reed
# Arthur Flores
#
#
#
# Zach Ward

# %%
! which pip
# Out:
# /home/avijit/venv/bin/pip

# %%
# Out:
# /bin/sh: 1: nvidia-smi: not found

# %%
nc_dir = '/home/piotr/voter-records-nc/'

# %%
import csv
import numpy as np
import zipfile
from tqdm import tqdm

# %%
edic = {}
gdic = {}
def load(infile):
        races = set([])
        eths = set([])
        data = []
        with open(infile, encoding='utf-8', errors='ignore') as csvfile:
            reader = csv.reader(csvfile, delimiter = '\t', quotechar='"')
            first = True
            for row in tqdm(reader):
                if first:
                    first = False
                    continue

                last = row[9]
                first = row[10]
                middle = row[11]
                city = row[14]
                state = 'NC'
                zipcode = row[16]
                race = row[25]
                races.add(race)
                ethnic = row[26]
                eths.add(ethnic)
                gender = row[28]
                status = row[4]
                party = row[27]
                age = row[29]
                if race+'_'+ethnic not in edic:
                    edic[race+'_'+ethnic]=[]
                edic[race+'_'+ethnic].append(first+" "+middle+" "+last)
                if gender not in gdic:
                    gdic[gender]=[]
                gdic[gender].append(first+" "+middle+" "+last)
#  'CHARISMA E ALLEN',
#  'JAMIE L ALLEN',
#  'KONNESHA I ALLEN',
#  'SHARON JEFFRIES ALLEN',
#  'SANDRA CAGLE ALLEN-MORTON',
#  'LUTHER ONEAL ALLISON',
#  'DEATRA FOSTER ALLRED',
#  'AMANDA MARIE ALSTON',
#  'CORNISA MARIE ALSTON',
#  'EBONY KIERA ALSTON',
#  'KELLY ANN ALSTON',
#  'SAUNDERS CLARENCE ALSTON',
#  'MIANA JOY ALVARADO',
#  'ROBERT ANDREW ALVARADO',
#  'CLAUDIA  ALVAREZ',
#  'JEFFERSON  ALVAREZ',
#  'CARLY RENEE ALVES',
#  'DAVID ULADIMIR AMAYA',
#  'TRINITY KATHRYN AMBROSE',
#  'SHAILJA  AMIN',
#  'CHRISTOPHER WILLIAM ANARFI',
#  'ANTHONY LEE ANDERSON',
#  'COLLYN MICHAEL ANDERSON',
#  'ISAAC REESE ANDERSON',
#  'KRAIG COREY ANDERSON',
#  'CARLOS ALBERTO ANDINO',
#  'MORGAN WILLIS ANDROZZI',
#  'XERNAY  ANIWAR',
#  'BOBBIE JO ANLIKER',
#  'KRISTYN NOELLE ANSELMO',
#  'OSVALDO  ANTONEZ',
#  'KAREN CRISTINA ANTUNEZ',
#  'MIGUEL ANGEL APARICIO',
#  'JOHN ROBERT APPLE',
#  'MELISSA ANN APPLE',
#  'JAVIER  AQUINO',
#  'SCOTT ANTHONY ARGUS',
#  'BRIAN ALEXANDER ARIZMENDI',
#  'TINA D ARMENTA',
#  'JACOB ANDREW ARMENTROUT',
#  'JULIA HOLLISTER ARMIGER',
#  'CHRISTOPHER BLAKE ARMISTEAD',
#  'SAMANTHA ELIZABETH ARNOLD',
#  'LATANJA KIERRA ARRINGTON',
#  'RONALD BRADFORD ARSLAN',
#  'DWAYNE ERIC ARTIS',
#  'JOSEPH COLEMAN ASHLEY',
#  'KINNANT JANENE ASHLEY',
#  'CLINT BRADY ATKINS',
#  'CRYSTAL DANIELLE ATKINS',
#  'DANIELLE PATRICE ATKINS',
#  'SHIFAY LASHELLE ATWATER',
#  'CHRISTOPHER J AUDINO',
#  'BRIAN PATRICK AUHER',
#  'JO-ANN SHORE AUMAN',
#  'KEVIN MILES ZEPHANIAH AUSTIN',
#  'PAYTON ASHLEIGH AVCHENBACH',
#  'KRISANN LEE AVENDANO',
#  'JEANETTE  AVERY',
#  'JACOB WILLIAM AYALA',
#  'DARIS LAWSON AYERS',
#  'DARRELL ALAN BABER',
#  'COURTNEY DAWN BADSTEIN',
#  'QUAYNE PAKIYA BAGLEY',
#  'BLANCA RUBID BAHENA',
#  'FRANCES LYNCH BAILEY',
#  'JEREMY RYAN BAILEY',
#  'PHORTASHIO DE CHELLE BAILEY',
#  'TAMMY MICHELLE BAK',
#  'EDWARD HUGHES BAKER',
#  'MICHAEL LAWAN BAKER',
#  'QUANTEESHA TAUNTIALA BAKER',
#  'REID JOHNSON BAKER',
#  'JESSICA JACKSON BALDOVINOS',
#  'EDWINA S BALDWIN',
#  'JAMIE MONTREL BALDWIN',
#  'JUDITH ANDERSON BALDWIN',
#  'QUENANTONI AMEEN BALDWIN',
#  'PATRICIA ANN BALES',
#  'AARON GRANT BALLARD',
#  'GREGORY ALLEN BALOG',
#  'BENJAMIN ASSOUMOU BANI',
#  'JORDAN NICOLE BANTA',
#  'KURTIS SCOTT BANVILLE',
#  'MARY ELIZABETH BARBER',
#  'MELISSA SUE BARILLA',
#  'VICKEY CRUTCHFIELD BARNETT',
#  'JENNA LEIGH BARONE',
#  'DAVID ANDREW BARRETT',
#  'VONCYLLA LAVETT BARRETT',
#  'BRIAN MARK BARRINGER',
#  'AURORA CANTU BARRON',
#  'DUSTIN HARLY BARROW',
#  'ANNA  BARSON',
#  'ADAM NATHAN BASS',
#  'MARKEITH KEJAUN BASS',
#  'DWIGHT SAMUEL BATTLE',
#  "ZYHR'A LAKRYV'A BATTLES",
#  'ALEX  BAUTISTA SOSA',
#  'KAROLE ANN BAYER',
#  'DAVID LEE BEALE',
#  'JOHN DAVID BEARD',
#  'MARY CYNTHIA BEARD',
#  'CHARLES ALLEN BEASLEY',
#  'MEGAN CARTER BEASLEY',
#  'JEANETTE  BEAUCLAIR',
#  'BRENT  BEAULIEU',
#  'DANIEL GEORGE BEBEE',
#  'BRENNA CLAIRE BECKELMAN',
#  'SIMONE  BECKER',
#  'EVERETT C BECKNELL',
#  'JANICE JUANITA BECKWITH',
#  'JORDAN MATTHEW BEHNFELDT',
#  'SUSAN DUDLEY BELANGIA',
#  'BROOKE ALEXANDREA BELCHER',
#  'RONALD THOMAS BELL',
#  'WILLIAM DOUGLAS BELL',
#  'KELVIN LAMORSE BELLE',
#  'JUSTIN CHARLES BELLINGER',
#  'CAITLYN JEAN BELMONTE',
#  'CARLOS ABNER BELTRAN',
#  'ERNESTO RAUL BENBASSAT',
#  'DOROTHY MAE BENBOW',
#  'JAMIE LYNN BENFIELD',
#  'JEFFREY LEE BENNETT',
#  'KIMBERLY SCHNELL BENNETT',
#  'LAURA DOLORES BENNETT',
#  'SANDRA DEE BENNETT',
#  'NICHOLAS  BENSON',
#  'JOYCELYN SEQUERIA BENTLEY',
#  'WILLIE M BENTON',
#  'ELEANOR DOLEN BENTZ',
#  'BRANDON MICHAEL BERGEVINE',
#  'MEREDITH LOUISA BERK',
#  'TYLER DUSTIN BERTOLONE',
#  'MARY LOUISE BEST',
#  'TERRENCE CARTER BETHEA',
#  'HANNA ROSE BIEBEL',
#  'JACQUELINE Y BIGELOW',
#  'LOVELY LYNETTE BIGELOW',
#  'MARK ERIC BIGELOW',
#  'MARTIN RANDALL BILLINGSLEY',
#  'AMANDA MARIE BIONDI',
#  'MICHAEL FRANCIS BIONDO',
#  'COLLEEN MARY BISACCIO',
#  'ALLEN FOSTER BLACK',
#  'LORI ANN BLACK',
#  'STEPHEN DOUGLAS BLACK',
#  'RODNEY BLAKE BLACKWELL',
#  'MAXINE  BLADES',
#  'SHIRLEY YVONNE BLAND',
#  'SAMANTHA  BLANK',
#  'ROBERT WAYNE BLANKENSHIP',
#  'CYNTHIA LEIGH BLOUIN',
#  'LEAH HAMPTON BLUE',
#  'JESSIE VICTORIA BOAK',
#  'LAUREN ASHLEY BODIE',
#  'TREY KINCAID BOGGS',
#  'MARGARET KATHERINE BOGLE',
#  'SARA CHRISTINE BOIKE',
#  'BARBARA ANN BOLDEN',
#  'TRAVIS CLAYTON BOLICK',
#  'ASHLEY WARD BOLTON',
#  'JERRICA  BOLTON',
#  'MICHAEL BRANDON BONDURANT',
#  'DANIELLE  BONICHE',
#  'AGUEDA ELVIRA BONILLA-BRAVO',
#  'RETA FAYE BONNETTE',
#  'BETTY JEAN BORROR',
#  'MICHELLE DANIELLE BOSWELL',
#  'ROBIN LYNNMARIE BOWENS',
#  'CHRISTIAN SIPE BOWLES',
#  'RANDALL HUNTER BOWMAN',
#  'THOMAS BRYANT BOWMAN',
#  'BRADLEY MICHAEL BOXILL',
#  'VICTOR  BOYD',
#  'TESS CONNOR BOYLE',
#  'WENDY ANN BRAAT',
#  'ABIGAIL MARIE BRADBURY',
#  'DENZELL-CHAKU D BRADLEY',
#  'WILLIAM NORRIS BRADLEY',
#  'KARA MARIE BRADSHAW',
#  'CLIFTON L BRADSHER',
#  'DANIEL  BRADSHER',
#  'MARTHA ANN GREEN BRADY',
#  'CLELL  BRAGG',
#  'DANA LOUISE MCCRAY BRANCH',
#  'EMILY  BRASWELL',
#  'ANDERSON WADE BRAXTON',
#  'KELLY STORY BRAXTON',
#  'TIFFANY GAYLE BREASHEARS',
#  'TROY  BREASHEARS',
#  'LEAH V BREINDEL',
#  'QUINTIN  BRENNER',
#  'CHRISTOPHER DAVONTE JULIAN BRENT',
#  'ORAPIN  BRENT',
#  'GREGORY JOSEPH BRIEN',
#  'EILEEN MARY BRIGGS',
#  'JORDAN ALEXANDER BRIGGS',
#  'MICKEY JERRY BRIGGS',
#  'THOMAS DURWARD BRIGHAM',
#  'BRIA SHANTAE BRINCEFIELD',
#  'MIKAYLA LUIBOU BRINGMAN',
#  'RUBY ANNE BRINKERHOFF',
#  'JACKSON DEAN MOORE BRINKLEY',
#  'TRACI LYNNE BROADWELL',
#  'CARLEIGH DENISE BROOKS',
#  'DAVID JAYCE BROOKS',
#  'HELEN JOSEY BROOKS',
#  'WILLIAM EDWARD BROOKS',
#  'ANTHONY ROBERT BROWN',
#  'ASIA SYLOAN BROWN',
#  'BLAINE BERNEDETTE BROWN',
#  'CHRISTOPHER EUGENE BROWN',
#  'DARICK HAKEEM BROWN',
#  'DIANE CARTER BROWN',
#  'ERIC SINCLAIR BROWN',
#  'GIANA MICAIAH BROWN',
#  'JAMES  BROWN',
#  'JAMES DALTON BROWN',
#  'JIMMY LEE BROWN',
#  'JOSHUA THOMAS BROWN',
#  'LISA ISENHOUR BROWN',
#  'MARSHALL  BROWN',
#  'MICHAEL TYLER BROWN',
#  'RALPH NATHANIEL BROWN',
#  'JODY MICHAEL BROWNING',
#  'STEPHANIE CAROL BROWNING',
#  'JUSTIN TAYLOR BRUCE',
#  'JONATHAN MATTHEW BRUNGER',
#  'JAMES HAROLD BRUNK',
#  'LAURA ELIZABETH BRUSSEAU',
#  'AMY FEE BRUZZICHESI',
#  'SHELIA ANN BRYAN',
#  'CHRISTINA NICOLE BRYANT',
#  'ZACK LEWIS BRYANT',
#  'EMILY BYRD BUCHANAN',
#  'DAVID MICHAEL BUCK',
#  'MEGAN JANEL BUCKLEY',
#  'JOY NICHOLE BULLOCK',
#  'NIESHA LATRESA BURDEN',
#  'ANDREA ANTONIO BURGESS',
#  'SHELBY CAROL BURGESS',
#  'AIDAN JAMES BURK',
#  'DERICK CHARLES BURNETTE',
#  'KENRIC DONYELLE BURNETTE',
#  'LAURA  BURNETTE',
#  'ERIC WILLIAM BURNS',
#  'HEATHER THOMAS BURNS',
#  'RONNIE SHANE BURNS',
#  'NOAH ELLIS BURR',
#  'BRITTANY AMBER BURTON',
#  'JAMES EDWARD BURTON',
#  'WILLIAM JAMES BURTON',
#  'BRITTANY TIARA BURWELL',
#  'ARTHUR LAWRENCE BUSCH',
#  'ROBERT SAMUEL BUXTON',
#  'CONNIE WALTER BYERS',
#  'KELVINA RENEE CALDWELL',
#  'SHAWN ALEXANDER CALDWELL',
#  'PAUL ANTHONY CAMARDA',
#  'ANTHONY LEWIS CAMPBELL',
#  'KEVIN ALLEN CAMPBELL',
#  'ROBERTO  CAMPOS',
#  'JOSE RANULFO CAMPOS GONZALEZ',
#  'DONALD RAY CANADA',
#  'GLORIA EDELMIRA CANALES',
#  'CHRISTIAN JAMAL CANNADY',
#  'ELIZABETH ANNE CANTO',
#  'AMARYLLIS  CANUTO',
#  'PATTY SUE CAPPS',
#  'FERMINA  CARACHURE',
#  'SHIRLEY MELANIE CARDENAS',
#  'CLAIRE JESSIE CARMAN',
#  'LULA VIRGINIA CARNELL',
#  'LANA  CAROLEE',
#  'VERNICIA LYNN CAROLINA',
#  'JEREMY JOSEPH PAUL CARON',
#  'SHANOBI RASHAAD CARPENTER',
#  'SYDNEY ALANE CARR',
#  'JAMES DENNIS CARREGAL',
#  'MONIQUE CATHERINE CARRENO',
#  'CATHY FIELDS CARROLL',
#  'ELIJAH  CARROLL',
#  'NICOLAS EDWARD CARROS',
#  'DONNA HAITHCOCK CARTER',
#  'JOHNNY RAY CARTER',
#  'JON MICHAEL CARTER',
#  'NANCY MAY CARTER',
#  'PRESTON EZEKIAL CASON',
#  'ELLEN MARIE CASSADY',
#  'KAHLI MARIE CASTAGNERA',
#  'ABIGAIL  CASTELLON-VIRVIA',
#  'JENNIFER MELISSA CASTILLO CORVERA',
#  'CHONTEL NICOLE CATES',
#  'TRACEY  CAVE',
#  'ANGEL LYNN CEJA',
#  'LAURA ANN CELLA',
#  'ANTONIA  CERDA URIETA',
#  'WALTER S CERULLI',
#  'JOHN MATTHEW CHAFATELLI',
#  'OLIVIA  CHAMBERLAIN',
#  'CRAIG MICHAEL CHAMBERS',
#  'BERNICE  CHANDLER',
#  'JACOB COLE CHATMON',
#  'ODALYS  CHAVEZ',
#  'IDALIS DEVON CHAVIS',
#  'SHEREA CHANTEL CHAVIS',
#  'SUE HURLEY CHEEK',
#  'BRIAN  CHEN',
#  'ERICA CHERELLE CHERRY',
#  'MITSURU  CHIBA',
#  'SUSAN  CHIKHA',
#  'TAYLOR LAUREN CHILDRESS',
#  'PHYLLIS GAY CHRISCO',
#  'TRAVERAS TRENTEN CHRISP',
#  'DIANE TINSLEY CHRISTIAN',
#  'KATIE LEIGH CHUNG',
#  'VANIA JASMINE CLAIBORNE',
#  'BENJAMIN LEE CLAPP',
#  'AMBER  CLARK',
#  'BERDAL MEKO JORDAN CLARK',
#  'DARYL WAYNE CLARK',
#  'DEANNA LAVERN CLARK',
#  'DEMAIYA NYSHAY CLARK',
#  'DEXTER MAURICE CLARK',
#  'JASON ALEXANDER CLARK',
#  'KENDRA SHANELL CLARK',
#  'TEMESHA NICOLE CLARK',
#  'TEVIN DELSHAWN CLARK',
#  'TIFFANY MACHIAL CLARK',
#  'JOSHUA DANIEL CLAYTON',
#  'MALLORY ANN CLAYTON',
#  'TOBY GORDON CLAYTON',
#  'MAE ELLEN CLEGG',
#  'JEREMY DREW CLEVENGER',
#  'CHANTEL ROBYN CLICK',
#  'HARLEA MICHELLE CLIFTON',
#  'MARGARET ANN CLOHAN',
#  'STEPHEN BRET COBB',
#  'ANITA JO COBLE',
#  'JAMES DYLAN COBLE',
#  'RICKY GRAY COBLE',
#  'SKYLAR LEE COBLE',
#  'JON CHRISTOPHER COCKERHAM',
#  'CRYSTAL LARAE COCKMAN',
#  'SAVANAH MARIE COE',
#  'CARRYN LINN COHEA',
#  'AISHA THIGPEN COHEN',
#  'TARA ELIZABETH COLE',
#  'CASSIDY BROOKE COLEMAN',
#  'REBEKA LYN COLEMAN',
#  'WILLIAM LOUIS COLEMAN',
#  'NATASHA YVETTE COLEMAN PULLEN',
#  'BRIAN CHARLES COLLIER',
#  'CAITLYN MARIE COLLIER',
#  'GINA MARIE COLLIER',
#  'TAYLOR WHITNEY COLLIER',
#  'JARED EVERETT COLLINS',
#  'SARA DANIELLE COLLINS',
#  'BETTY PAYLOR COLTON',
#  'PATRICIA TINNIN COLTRANE',
#  'FRANK  COMBS',
#  'ANTHONY  COMORENO',
#  'MITCHELL POTTER COMPTON',
#  'MARIEL LEA CONLON',
#  'KATHERINE SOUTHARD CONNER',
#  'NICHOLAS ROBERT CONRAD',
#  'BRANDI ELIZABETH CONSTANTINO',
#  'BRADLEY WAYNE COOK',
#  'STACY RENEE COOK',
#  'OLGA MONSANTO COOPER',
#  'RYAN MICHAEL COOPER',
#  'ERIKA LYNETTE COOPER ALBRIGHT',
#  'KIMBERLY DENA COPELAND',
#  'JAIQUAN JANDARI CORBETT',
#  'SHELIA RENEE CORBETT',
#  'JUAN  CORDOVA',
#  'JUSTIN RAY CORWIN',
#  'ANNAMARIE CHRISTINE CORY',
#  'NICOLE PATRICIA COSGROVE',
#  'JASMINE MONIQUE COUNCIL',
#  'DORIAN NIKELL COUSIN',
#  'KAMEELAH SABRINA COVINGTON',
#  'NATASHA DANIELLE COVINGTON',
#  'SKYLER AMY COWANS',
#  'CHARLES MICHAEL COX',
#  'JAKHI K COX',
#  'JUNE MARIE COX',
#  'SONYA RICHELE COX',
#  'MADELINE BELLE CRAFT',
#  'COURTNEY  CRAIG',
#  'JUDITH ROSEANN CRAVEN',
#  'EDWARD GRAHAM CRAWFORD',
#  'ROSA CATHERINE CREECH',
#  'KEITH EUGENE CRESPO',
#  'TYLER JEREMEY CRIMA',
#  'AREEANA  CRISP',
#  'KEYMIAN LEVANTE CRISP',
#  'TERRY LAMONT CRISP',
#  'DAMORIS TERRELL CRITTLE',
#  'DARIUS TYRIQ CROMEDY',
#  'MONTE DREW CROSIER',
#  'KEVIN DECEMBER CROSS',
#  'JASON WAYNE CROY',
#  'CARISA NOEL CRUMPLER',
#  'CHARLES JOHNSTON CRUMPTON',
#  'ANALAURA  CRUZ',
#  'BRITTANY D CRUZ',
#  'JESUS  CRUZ',
#  'MELISSA MARIE CRUZ PACHECO',
#  'ANGEL DAVIS CUMMINGS',
#  'ANTHONY REGINALD CURRIE',
#  'ALVIN TIMOTHY CURRY',
#  'PEGGY JEAN CURRY',
#  'JORDAN BLAKE CURTIS',
#  'KELLEY DONNIELLE CURTIS',
#  'MARILYN MARTIN CURTIS',
#  'MEGAN POLLOCK CUTHRELL',
#  'DAISY YOMAYRA CUZCO',
#  'RYAN LAMAR DAILEY',
#  'TERESA KERR DALRYMPLE',
#  'JEFFREY LYNN DALTON',
#  'MATTHEW BRYAN DALTON',
#  'TERESA DIANNE DAMERON',
#  'CAITLYN NICOLE DANGAARD',
#  'KAITLYN NICOLE DANIEL',
#  'TRAMAYNE SHAKIA DANIEL',
#  'JAHNEA KALIA DARBY',
#  'AARON BARRY DARK',
#  'MICHELLE RENEA DAVENPORT',
#  'WILLIE KARL DAVENPORT',
#  'JAKE MICHAEL DAVIDOFF',
#  'ANGELA SWANGER DAVIS',
#  'DARRON KEITH DAVIS',
#  'JENNIFER NICHOLE DAVIS',
#  'JESSICA LANKFORD DAVIS',
#  'MANDRELL EDWARD DAVIS',
#  'REGINA LYNN DAVIS',
#  'ROBIN ELANIA DAVIS',
#  'TIMOTHY C DAVIS',
#  'ZACHARY CHASE DAVIS',
#  'MARGARET LEIGH DAVIS FERETTINO',
#  'JUSTIN PHILIP DAVISSON',
#  'KARI RENEE DAWSON',
#  'ALEXANDER GARRETT DAY',
#  'BETTIE HESTER DAY',
#  'ELIZABETH WILLONA DAY',
#  'KRISTEN DENISE DAY',
#  'SHARON DENISE DAY',
#  'ASHLEE NICOLE DAYE',
#  'SYLVIA VAUGHN DAYE',
#  'MICHELLE  DE JESUS',
#  'CARL JOSEPH DEBRULER',
#  'CYNTHIA ANNE DECOU',
#  'DOMINICK SAM DEFELICE',
#  'CALVIN  DEGRAFFENREIDT',
#  'TAYLOR LYLE DEHART',
#  'NICKLAUS JORDAN DELARIO',
#  'JOSHUA MICHAEL DELL',
#  'DOMINIC ANTHONY DEMARCO',
#  'LOUIS D DEMARCO',
#  'JANIE DAUPHINE DEMARRA',
#  'BRITTANY LYNN DEMIS',
#  'JESSICA LOGAN DENNIS',
#  'KEVIN ANDREW DENNIS',
#  'SHANON BLAIR DENNIS',
#  'CHRISTOPHER BRAD DENNY',
#  'NOAH DANIEL DESIMONE',
#  'BRADFORD STEVEN DEVOE',
#  'DANIEL NORMAN DEVOE',
#  'DANIEL PAUL DI MEO',
#  'REBECCA VICTORIA DIAS',
#  'ANGEL MANUEL DIAZ',
#  'ADRIANA  DIAZ PORTILLO',
#  'GAVIN TAYLOR DICKEN',
#  'CLARK EDWARD DICKENS',
#  'ERICA DELLINGER DICKENS',
#  'JOHNSIE HALL DICKERSON',
#  'TELVIN JARROD DICKEY',
#  'SAMANTHA LYNN DICOSTANZO',
#  'KRISTINA MICHELLE DIEDWARDO',
#  'DANONNA DOMINIQUE DIGGS',
#  'MARY RACHAEL DIMONT',
#  'MICHAEL JOHN DIMSON',
#  'JENNA CHRISTINE DIPRIMA',
#  'LINDSEY DANIELLE DISHNER',
#  'AVIS VEONNE DIXON',
#  'CHRISTOPHER DEMARIO DIXON',
#  'GREGORY ALLEN DIXON',
#  "JEREMY LE'RAY DIXON",
#  'PAM BROWN DIXON',
#  'MARSHA NEWTON DOBY',
#  'HEATHER MARIE DOCKRILL',
#  'MELINDA D DODSON',
#  'WIESLAWA TERESA DOEBLER',
#  'WILLIAM DALE DOLLAR',
#  'WALTER  DOMEYKO',
#  'SAMANTHA RYAN DONLEY',
#  'ALYSSA LEA DONOHUE',
#  'TAIESHA LADAWN DORSEY',
#  'JOHN WILSON DORWARD',
#  'PARKER GORDON DOUGLAS',
#  'JIMMY  DOWNEY',
#  'AIDAN JAMES DRAPER',
#  'ELVIS EUGENE DRAUGHN',
#  'TIMOTHY LEE DRAUGHN',
#  'TAYLOR  DRUMMOND',
#  'MICHAEL ANTHONY DU LANEY',
#  'SIGFREDO  DUARTE',
#  'RICHARD RUCKER DUDLEY',
#  'JOSHUA LEWIS DUGGINS',
#  'WILLIAM RAVARA DUHAYLUNGSOD',
#  'JOHN E DUKE',
#  'WILLIAM WESLEY GRANT DULING',
#  'MICHAEL THOMAS DULL',
#  'HALEY RAE DUNCAN',
#  'JESSE LEE DUNCAN',
#  'BRANDON JAMES DUNHAM',
#  'LOGAN BLAIR DUNN',
#  'TIFFANY LORRAINE DUNN',
#  'HANH NGOC DUONG',
#  'BAYLEY LEIGHANN DURHAM',
#  'ELEANOR ABIGAIL DURVIN',
#  'LINDA JULIE DUTHIERS',
#  'YASMEEN GHASSAN DWEIK',
#  'JOHN KEVIN DWYER',
#  'WILLIAM JOHN DWYER',
#  'LACEY ANNMARIE DYER',
#  'AARON DONNELL EASTERLING',
#  'CHARLES BARRY ECKMAN',
#  'HELEN TEPFER ECKMAN',
#  'AMBER NICOLE ECTOR NICKERSON',
#  'DOUGLAS BLAINE EDMUNDS',
#  'BILLY EDGAR EDWARDS',
#  'ERICA MARIE EDWARDS',
#  'KRISTEN ANN EDWARDS',
#  'LAKEYSHA ALJERNAE EDWARDS',
#  'YVETTE MICHELLE EDWARDS',
#  'WHITNEY KATHLEEN EDWARDS RUSSELL',
#  'HANNAH REKEALTH EGELAND',
#  'JULIA  EHPAW',
#  'HARVEY LEE EICHNER',
#  'KARA I ELCIK',
#  'STACHA NICOLE ELLIOTT',
#  'RITA MASON ELLIS',
#  'TYNISHA RASHONDA ELLIS',
#  'JAMES LUTHER ELLISON',
#  'SARAH MOSTAFA ELY',
#  'ERIC MICHAEL EMERINE',
#  'BRITTANY NOELLE EMERSON',
#  'RODNEY BLANE FOX EMERY',
#  'PAUL DAVID EMMERLING',
#  'ANTHONY TYLER ENLOW',
#  'JERRY DONNELL ENOCH',
#  'KAMIEN JAMEL ENOCH',
#  'LAKEISHA NICOLE ENOCH',
#  'PATRICIA ANN ENOCH',
#  'RAY SHAWN ENOCH',
#  'HUNTER FRANK ERWIN',
#  'KATIE TRAPP ERWIN',
#  'ERIKA GAIL ESCOBAR',
#  'WILLIAM ALBERTO ESCOBAR',
#  'CANDACE OLIVIA ESSICK',
#  'SANJUANITA S ESTEBAN',
#  'TONY D EUBANKS',
#  'HERVET NAKIA EVANS',
#  'REBECCA CHRISTINE EVANS',
#  'TRACY VONDELLE EVANS',
#  'TRAY ANTONIO EVANS',
#  'AMANDA  EVERETT',
#  'JOEY  EVERETT',
#  'SHALISHA ARVEYAH EVERETT',
#  'RACHEL JANE EWALD',
#  'TERRY LYN EWING',
#  'DINA  EXAVIER',
#  'DEBRA MCGEE FABISH',
#  'JOSH SCOTT FACTOR',
#  'KELLY RENEE FADDOUL',
#  'THOMAS ANTHONY FAIRCLOTH',
#  'DYLAN RAY FALCONER',
#  'ALLEN STUART FARABEE',
#  'KRISTIE ANNE FARLOW',
#  'LAUREN NICOLE FARMER',
#  'MICHELLE PERRY FARMER',
#  'ROBERT JOHN FARMER',
#  'JAYLEN LATTREL FARRIS',
#  'THOMAS PERRY FARTHING',
#  'DAMOND JAMEL FAUCETTE',
#  'DIONDREA  FAUCETTE',
#  'ROBERT ALLEN FAUCETTE',
#  'DONNEL MALIK FAULK',
#  'BRIGETT SHEA FAULKNER',
#  'DARISHUA LECHELLE FAULKNER',
#  'BRITTANY NICHELLE FEASTER',
#  'KATERINA  FEDOROWICZ',
#  'LUIS GILBERTO FELICIANO',
#  'TINA ROSA FELICIANO',
#  'DAKOTAH EUGENE FENDLEY',
#  'CHAD WAYNE FERGUSON',
#  'SEAN  FERGUSON',
#  'JOSE LUIS FERNANDEZ PANEQUE',
#  'MARIO DEVON FIELDS',
#  'ROBERTA DEERE FIELDS',
#  'MANUEL QUIAMBAO FIGUEROA',
#  'KENNETH THOMAS FIKES',
#  'SHARON M FIKES',
#  'PAUL ADOLPHUS FINDLAY',
#  'DAVID CHARLES FISTNER',
#  'NORA JOYCE FITZWILLIAM',
#  'ROBERT OLADELA FLACK',
#  'KELLY ELIZABETH FLEMING',
#  'MENDY NEESE FLETCHER',
#  'NAOMI B FLORENCE',
#  'JUANITA MALTIDE FLORES-OLMOS',
#  'BRYANNA MIDDIE FLYNN',
#  'MEGAN TAYLOR FLYNN',
#  'JORDAN BRIAN FOGEL',
#  'ANGELA KING FOGLEMAN',
#  'SAMANTHA LOUISE FORBES',
#  'LISA KATHLEEN FORSTER',
#  'DEBBIE CAROL FOSTER',
#  'KRYSTINE ASHLEY FOSTER',
#  'SHEENA MICHELLE FOSTER',
#  'TRINA ELIZABETH FOSTER',
#  'MORGAN ELIZABETH FOUSHEE',
#  'SITI ZAHDRA FOUSHEE',
#  'CHRISTOPHER LAWRENCE FOUST',
#  'JENNY L FOUST',
#  'RANDOLPH LEE FOX',
#  'JAMIE FLEMING FRAMPTON',
#  'BRENT LYNN FRANCIS',
#  'BETSY MARCELLIE FRANCO',
#  'BRAELINN MARIE FRANK',
#  'AMY RICE FRANKLIN',
#  'CHRISTOPHER ROSS FRANKLIN',
#  'KRISTEN MICHELLE FRANZE',
#  'ELIZABETH ANNE FRASER',
#  'PAULA MICHELLE FRATAZZI',
#  'VINCENT WILLIAM FRATAZZI',
#  'ELAINA MICHELLE FRAUSTO',
#  'DARRELL HASSAN FREEMAN',
#  'LENNOX CLARKE FREEMAN',
#  'TYLER MASON FREEMAN',
#  'ANEICIA DIANE FREI',
#  'EMILY ELIZABETH FREIRICH',
#  'SCOTT BRADLEY FRENCH',
#  'STEPHEN WILLIAM FRENCH',
#  'TRAVIS WARREN FRENCH',
#  'CHRISTINE LYNNE FREW',
#  'NEAL STRATTON FRICKS',
#  'ASHLEY NICOLE FRYE',
#  'KASEY RENEE FRYE',
#  'LAUREN TIFFANY FULCHER',
#  'MARIA TERESA FULFORD',
#  'ARCHIE KING FULLER',
#  'JAVON KALOM FUNCHESS',
#  'JOHN RAY FUQUAY',
#  'LINDA CARMICHAEL FUQUAY',
#  'MATTHEW CHARLES FURLONG',
#  'LESLIE  FURNESS',
#  'KELSEY NICOLE GABEL',
#  'DONALD LYNN GADDY',
#  'DAVID LAURENT GAGNE',
#  'AALIYAH SHAQUELLE GALLOWAY',
#  'BETSY MARTIN GALLOWAY',
#  'MAURICIO OLIVER GALVEZ',
#  'CAROL ANN GAMBRELL',
#  'RAJ  GANDHI',
#  'JONAH VANICE GANT',
#  'ANGELA OVERMAN GANTT',
#  'ADRIAN  GARCIA',
#  'HENRY  GARCIA',
#  'ISABELA JACQUELINE GARCIA',
#  'MANUEL A GARCIA',
#  'CLYDE BROOKS GARDNER',
#  'REIS JAMES GARDNER',
#  'SHAWN MICHAEL GARDNER',
#  'LEIGH ANNE GARRARD',
#  'BRYAN DAVID GARRETT',
#  'JAMEL KESHON ROME GARRETT',
#  'WILLARD O GARRETT',
#  'JESSICA EVERETTE GARSIDE',
#  'JERMEIA LASHEA GASKINS',
#  'BRANDON JERMAINE GASNINS',
#  'ANNA BODINE GASPARI',
#  'VONDA L GATLING',
#  'JACOB  GAUER',
#  'CARLEY BETH GAYNES',
#  'CATHARINE LOUISA GENSEL',
#  'ANDREA RAE GENTRY-APPLE',
#  'BRANDON MICHAEL GEORGE',
#  'FELICIA HESTER GEORGE',
#  'TAMARA NICOLE GEORGE',
#  'GABRIEL ZEN GERMINO',
#  'RICHARD TODD GERRINGER',
#  'AARON THOMAS GETZ',
#  'JENNIFER ASHLEY GIBBONS',
#  'COLE RICHARD GIBSON',
#  'DIANNA OLIVIA GIL JAIME',
#  'RYAN DAVIS GILL',
#  'AMANDA ANNE GILLEY',
#  'AMBREA PAISLEY GILLIAM',
#  'MICHAEL ELLIOTT GILLIAM',
#  'VICKY LYNN GILLOW',
#  'GEORGE LORENZO GILMORE',
#  'LOREN ASHELY GILMORE',
#  'ELIZABETH LOUISE GILSON',
#  'KERRY LYNN GITTLE',
#  'CHRISTINE MARIE GJERTSON',
#  'KEJA ALEXIS GLASS',
#  'GARRY LEE GLOSSON',
#  'YOLANDA BIVENS GODWIN',
#  'HOLLY MELISSA GOIST',
#  'DANIELLE GRACE GOLINSKI',
#  'WALTER ALAIN GOMEZ HERNANDEZ',
#  'KYLEE REESE GOMILLA',
#  'IVAN ALEXANDER GONZALEZ',
#  'JAMIE LYNN GONZALEZ',
#  'AMY ELIZABETH GOOD',
#  'ELIZABETH SALISBURY GORDON',
#  'INDIGO AMELIA GORDON',
#  'MEGAN ABRIELLE GOSLER',
#  'SARA ROSE GOSTOMSKI',
#  'RYAN WILLIAM GOTSHALL',
#  'JEFFREY ALLEN GRADY',
#  'MARGIE MARIE GRAHAM',
#  'WILLIAM RHODES GRAHAM',
#  'ANGELA KEESEE GRAINGER',
#  'REBECCA GLENN GRANDSTAFF',
#  'HEATHER LERAE GRANT',
#  'PATRICIA ANN GRATE',
#  'TIMOTHY KELVIN GRATE',
#  'JAQAE  GRAVES',
#  'JOHN WILLIAM GRAVES',
#  'REMI  GRAVES',
#  'STACY LORENZO GRAVES',
#  'CORNELIUS LEONARD GRAY',
#  'MIKAYLA  GRAY',
#  'DANIEL MCCRAY GREEN',
#  'DORA RENEE GREEN',
#  'PARKER ELLIS GREEN',
#  'ELIZABETH FRANCES GREENBERG',
#  'EMILY MORGAN GREENE',
#  'GAIER THOMAS GREER',
#  'GERALDINE PULLEY GREESON',
#  'MICHELLE LYNN GREGAN',
#  'CORO  GREGGAR',
#  'PAGE SARTIN GREGORY',
#  'HEATHER WALL GREINER',
#  'WINDY RENE GRIFFIN',
#  'DANA LYN GRIZZEL',
#  'JANET ROBERTSON GRIZZLE',
#  'HAZEL BROWN GROCE',
#  'BRENDA DIXON GROGAN',
#  'SANDRA LYNN GROOM',
#  'TINA RENEE GROOMS',
#  'CHARLES DAVID GROSS',
#  'KIMBERLY ANN GROVER',
#  'ESPERANZA  GUAMAN REVELO',
#  'JOSE LUIS RAMIREZ GUERRERO',
#  'LAURA CATHERINE GUIDRY',
#  'DANIEL  GUIJOSA',
#  'CHRISTINE ELIZABETH GUIMARAES',
#  'ROBIN RICHARD GULLEDGE',
#  'SHIRELL DIANA GULLEY',
#  'JEFFREY DYLAN GUNTER',
#  'KATHARINE PATRICIA GUNTHER',
#  'HEATHER LYNN GURACK',
#  'JULIE ANNETTE GURLEY',
#  'CALEB TRISTON GUTHRIE',
#  'ROXANNA E GUTIERREZ',
#  'JENNIFER ANNE GUY',
#  'ABBY MELISSA GWYN',
#  'LENARD  GWYNN',
#  'MATTHEW NEAL GWYNN',
#  'SUSAN LINDSAY HAHN',
#  'SAMUEL JULIAN HAIGLER',
#  'LAURA LOVE HAILEY',
#  'JOSHUA JAMES HAINES',
#  'GREG ONEIL HAITH',
#  'SHEENA MARNECE HAITH',
#  'JACOB STROUD HAKES',
#  'YASSER MOHAMMAD HALAIKAH',
#  'DANIEL ERIC HALL',
#  'LACY VICTORIA HALL',
#  'PEGGY LOIS HALL',
#  'ROY R HALL',
#  'SHEEMA MARIE HALLAJI',
#  'CRAIG ANDREW HALLORAN',
#  'KELLI RENEE HAMBLEN',
#  'NICHOLAS LLOYD HAMILTON',
#  'JAMES KARRELL HAMLET',
#  'JARMAL ANTONIO HAMN',
#  'KIMBERLY YOLANDA HAMPTON',
#  'SHERRI SMITHEY HANCOCK',
#  'WILLIAM JAMES HANNA',
#  'NIRANJAN  HARALALKA',
#  'MANDY RHAE HARDEN',
#  'RACHEL MAZEJKA HARDIN',
#  'SABRINA  HARDIN',
#  'BRANDON TRAVIS HARDY',
#  'PRESTON CHRISTOPHER HARDY',
#  'MICHAEL  HAREWOOD',
#  'ELEANOR K HARGROVE',
#  'LAURYN MICHELLE HARPER',
#  'HOUSTON JAMES HARRELL',
#  'TAKIYAH ESHE HARRELL',
#  'RONALD KIRK HARRILL',
#  'STACY WILLIAM HARRINGTON',
#  'CASEY IRENE HARRIS',
#  'DONALD RAY HARRIS',
#  'KYREE T HARRIS',
#  'RUBY DINELL HARRIS',
#  'RUTHIE M HARRIS',
#  'SHIRLEY GARDNER HARRIS',
#  'STELLA MAE HARRIS',
#  'TAMIYA SANAA HARRIS',
#  'WILLIAM ERNEST HARRIS',
#  'AMY OAKLEY HARRISON',
#  'DANIELLE SIMONE HARRISON',
#  'JEROME JERMAINE HARRISON',
#  'ROBERT BLAKE HARRISON',
#  'RONALD BRADLEY HARRISON',
#  'TYLER LEE HARRISON',
#  'WILLIAM GLENN HARRISON',
#  'FELICIA SHANTE HARVEY',
#  'MONIQUE NICHELLE HARVEY',
#  'WILLIE DJUAN HARVEY',
#  'TERESA THOMPSON HASKINS',
#  'DENNIS CEDRIC HATFIELD',
#  'MAE ELLEN HATFIELD',
#  'STELLA KAY HATFIELD',
#  'ANDREW MARSHALL HATLEY',
#  'MARY KATHLEEN HAUFFE',
#  'ABIGAYLE KATHERINE HAVENS',
#  'BETH VIA HAWKEY',
#  'MARY GAY HAWKINS',
#  'PHILLIP BRIAN HAWKINS',
#  'SARAH MEREDITH HAYDN',
#  'TRACEY R HAYES',
#  'ASIA MONE HAYNES',
#  'BETH ANNE HEADER',
#  'KENDRA HILL HEATH',
#  'MARTHA ELIZABETH HEATH',
#  'RICHARD PAUL HECKSHER',
#  'CHRISTOPHER MARK HEINISCH',
#  'KATIE LEA HELMS',
#  'CANDICE MARIE HELTON',
#  'CASEY DENISE HEMBRICK',
#  'JUDY GRAGG HEMENWAY',
#  'SHEKINAH KALIFA PROMISE HEMINGWAY',
#  'AARON JAMES HENDERSON',
#  'NOAH CRAIG HENDERSON',
#  'ROSE L HENDERSON',
#  'JENNIFER ANN HENES',
#  'MARIA ELENA HENRIQUEZ',
#  'HANNAH CAROLINE HENRY',
#  'JAMES MICHAEL HERBIN',
#  'ANTONY LAGUNES HERNANDEZ',
#  'CELSA C HERNANDEZ',
#  'CHRISTOPHER  HERNANDEZ',
#  'GLADYS  HERNANDEZ',
#  'JUAN CARLOS HERNANDEZ',
#  'VERONICA ANN HERNANDEZ',
#  'JAMES JONATHAN HERNIAK',
#  'JENNIFER COLEMAN HERNLY',
#  'JAMES DEE HERRING',
#  'SOPHIE THOMPSON HERRING',
#  'ASHLEY SHANICE HESTER',
#  'ELLIOTT TYRELL HESTER',
#  'NORMAN CARL HESTER',
#  'LARIEN RENEE HESTER WILLIAMS',
#  'KELLIE MANN HICKS',
#  'KELSEY BROOKE HIGHFIELD',
#  'KATHERINE ANN HIGHT',
#  'GEORGE WAYNE HIGHTOWER',
#  'AARON POWELL HILL',
#  'BENNIE L HILL',
#  'ELIZABETH STEWART HILL',
#  'HILARY ERIN HILL',
#  'LINDSEY ELIZABETH HILL',
#  'LOGAN TAYLOR HILL',
#  'TRISTEN DALE HILL',
#  'ALEXANDRA RAE HILLEN',
#  'MICHAEL ANDREW HILLIARD',
#  'ASHLEY NICOLE HILTON',
#  'STOREY RANIER HINOJOSA',
#  'SCOTT EDWARD HINSHAW',
#  'AMANDA ALLISON HODGE',
#  'DOMINIQUE LUPORCHER HODGE',
#  'GARRET  HODGE',
#  'MICHAEL MILLS HODGE',
#  'DAVID GEORGE HODGENS',
#  'BRANDI MICHELLE HODGES',
#  'WILLIAM RAY HODGES',
#  'CHRISTOPHER IAN HODGIN',
#  'GABRIELLA DRAGO HOLDRIDGE',
#  'CHAD KINSEY HOLLAND',
#  'WHITTNI LINORE HOLLAND',
#  'DAKOTA LEE HOLLARS',
#  'LEAH MARIE HOLLAWAY MITCHELL',
#  'JIMMY PHILLIP HOLLOMAN',
#  'CHACORRIE GANEE HOLLOWAY',
#  'NANCY JANE HOLLY',
#  'SAMUEL MARK HOLMES',
#  'MATTHEW  HOLMS',
#  'JANIKE  HOLT',
#  'KIMBERLYN KELLY HOLT',
#  'CHERYL FAWN HORNUNG',
#  'ROBERT WAYNE HORTON',
#  'TAMMY LYNN HORTON',
#  'WALTER ALONZO HORTON',
#  'HALEY ELIZABETH HOSTETTER',
#  'DANIEL BAXTER HOUSTON',
#  'CHRISTOPHER READ HOWELL',
#  'CYNTHIA MULLINAX HOWELL',
#  'ROSE MARIE HOWLE',
#  'KATHERINE ANN HUDSON',
#  'DANIEL  HUFF',
#  'AUTUMN LEIGH HUFFINES',
#  'DANIEL RYAN HUFFMAN',
#  'STANTON VANCE HUFFMAN',
#  'DEBRA CAMPBELL HUGGINS',
#  'ALICIA DIANE HUGHES',
#  'ASHLEY NICOLE HUGHES',
#  'CHRISTOPHER  HUGHES',
#  'DONNA POLLARD HUGHES',
#  'ELENA KRISTINA HUGHES',
#  'EMILY ELISABETH HUGHES',
#  'SHANE MATTHEW HUGHES',
#  'ROBERT ANTHONY HUGHEY',
#  'SHANNA  HULSEY',
#  'RANDOLPH  HUNT',
#  'TILER ALEXANDRIA HUNT',
#  'CRYSTAL LYNN HUNTER',
#  'DAWN MARIE HUNTER',
#  'KELLY R HUNTER',
#  'JOHNATHON RAFAEL HUPRTA',
#  'SHANNON NICOLE HURLEY',
#  'JARED RAY HURT',
#  'DAISY  HURTADO',
#  'DAWN ROCHELLE HUTCHENS',
#  'RENEE DENISE HUX',
#  'EMILY CATHERINE HYLTON',
#  'LEA  HYNES',
#  'EMILY NICOLE ICE',
#  'RIDVAN  IDA',
#  'GABRIEL JOHN ILLES',
#  'SAMANTHA MARIE VON INGELHEIM',
#  'FAYE LEWIS INMAN',
#  'JUSTIN KENNETH INMAN',
#  'DELIGHT MICHELLE IRWIN',
#  'LANDON ELIZABETH ISAAC',
#  'ALEXANDRA MICHELLE ISLEY',
#  'KIMBERLY DEANNE ISLEY',
#  'ANNETTE SANDERS IVEY',
#  'THOMAS ANTHONY JACKOWSKI',
#  'ARRNGTON TYNEE JACKSON',
#  'JERI LYNN PHILLIPS JACKSON',
#  'JOHNATHAN ALAN JACKSON',
#  'PATTY WATSON JACKSON',
#  'FRANKLIN JUNIUS JACOBS',
#  'SIERRA ELENA JACOBS',
#  'TELISSA VONSHAYA JACOBS',
#  'JAVIER  JAIMES-AYALA',
#  'JEROME HARRISON JAMES',
#  'TERRENCE LEVON JAMES',
#  'KYLE PATRICK JANISCH',
#  'ELISHAH QUINN JANNEY',
#  'MICHAEL SHANE JARRETT',
#  'KEVIN THOMAS JARVIS',
#  'EMANI NIMIRRIA JEFFERIES',
#  'ALEXIS NICOLE JEFFERS',
#  'DEBORAH PUGH JEFFERSON',
#  'ADDIE JULIA JEFFREYS',
#  'RICKEY RECARDO JEFFRIES',
#  ...]

# %%
edic.keys()
# Out:
# dict_keys(['W_NL', 'W_UN', 'W_HL', 'O_NL', 'A_UN', 'B_NL', 'B_UN', 'O_UN', 'A_NL', 'U_UN', 'O_HL', 'M_NL', 'U_HL', 'M_UN', 'I_NL', 'U_NL', 'M_HL', 'A_HL', 'B_HL', 'I_UN', 'I_HL', ' _UN'])

# %%
edic['A_NL']
# Out:
# ['JOHN FUJIO ABE',
#  'ELSIE JOHN ABRAHAM',
#  'ANALYN ESTOQUE ABULOC',
#  'MAYANK JITENDRA ACHARYA',
#  'TAMARA LEE ADIBI',
#  'ARASI SWAMICKANNU ADKINS',
#  'NISARAHMAD  AKBARI',
#  'HONG VINH AU',
#  'NAI KO KO AUNG',
#  'HAMDA JABBAR AWAN',
#  'DAVID THIEN BANH',
#  'FELIX CANTO BASCO',
#  'VENON CANTO BASCO',
#  'CHARRO MAY GARCIA BAUZON',
#  'ALEXIS KEHAULANI BERGMANN',
#  'LA  BOUNHIENG',
#  'TITH  BOUNHIENG',
#  'MA CHARINA ILLESCAS BROOKS',
#  'SUSAN LEE BROWN',
#  'DIEP THI BUI',
#  'KIM DUNG BUI',
#  'NHAN T BUI',
#  'SAMANTHA DANPHUONG BUTLER',
#  'EDGAR SALVADOR JR ROMENA BUYCO',
#  'WILMAR CANO CABUANG',
#  'XIVLAN  CAO',
#  'BONN JORGE GONZALES CARVAJAL',
#  'HSIU-NIEN  CHANG',
#  'JOHN HANGSUK CHANG',
#  'MOHAMMAD TAYYAB CHAUDHRY',
#  'GULZARA SINGH CHEEMA',
#  'FENCHENG  CHEN',
#  'MISBAH NASIR CHHOTANI',
#  'RIZWANA NASIR CHHOTANI',
#  'TAMA  CLARKE',
#  'SPENCER JOSEPH-PAUL COFFEY',
#  'PAMELA LO COLM',
#  'KATHERINE MEICONG CONLIN',
#  'BUNYANECH DAWANGPA CORBETT',
#  'SHANEE DAVID COWLAND',
#  'ZAITOON YASMIN DADA',
#  'AMEE TANUJ DADHANIA',
#  'GIANG DINH DANG',
#  'JIMMY QUOCHUY DANG',
#  'SANG VAN DANG',
#  'HAI  DARY',
#  'EDGAR RAYMUND ARGAO DE JESUS',
#  'CHETAN VASANTRAO DESHMUKH',
#  'STEPHEN  DO',
#  'BICHVAN  DOAN',
#  'HOAI THUONG NGUYEN DOAN',
#  'THANH NGOC DOAN',
#  'ROGER TRI DONG',
#  'PHOUSAYKHAM  DOUANGPRACHANH',
#  'WEIWEI DAI DOUCETTE',
#  'JACK NGUYEN DRAB',
#  'LEONIDA PAGADOR DYKSTRA',
#  'STEVEN DAH EDISON',
#  'PAULA JONES FEARRINGTON',
#  'NICOLE JUNE FILIPPO',
#  'KIMBERLY MAKALUSKY FINARELLI',
#  'PARTH  GANDHI',
#  'HONG GOO GANG',
#  'RALPH PHILIPPE DIESTRO GARAY',
#  'JAMES FRANKLIN GESTY',
#  'SAYOKO  GORNTO',
#  'ADIAN  GOVENDER',
#  'JENAYE ARLENE GREENLEE',
#  'TAMI LEE GREENO',
#  'THIN  GYE',
#  'JIMMY THACH HA',
#  'VINH XUAN HA',
#  'YOSI CHA HALL',
#  'DEBBIE XAY HER',
#  'EDWIN  HONG',
#  'JENNIFER ERIN HOWARD',
#  'LAH K PRU  HSEE',
#  'HSER  HTOO',
#  'KEEGAN TAYLOR HUYNH',
#  'STEPHANIE  HUYNH',
#  'TYLER THANH KHOA LE HUYNH',
#  'AYESHAM  IMRAN',
#  'KHYLEA ANNE INTHAVONG',
#  'EMMANUEL JAVON JEFFERSON',
#  'REBECCA JANE JEFFRIES',
#  'CHUNG MUN JEONG',
#  'THUONG  KA',
#  'SUK TAE KANG',
#  'USHA SEHGAL KAPUR',
#  'DARAVANH  KAVANH',
#  'SRINIVASARAO  KAVIRAYUNI',
#  'BRADLY SOURIYOCHRIS KAYSONE',
#  'LIWEI  KETRON',
#  'ANTONIO  KHABANH',
#  'EIRIKA ALICIA KHALIFA',
#  'MAY  KHAMHUANTHONG',
#  'AMINA ALI KHAN',
#  'HUMZA FAROOQUE SULTAN KHAN',
#  'MUHAMMAD  KHAN',
#  'MACKENZIE ELIZABETH KIGER',
#  'JEAN  KIM',
#  'YOUNG NA KIM',
#  'RANVIR SINGH KITTANEY',
#  'MOSHAY THARMYAR KOH',
#  'WAH  KOH',
#  'PRIYANKA  KOHLI',
#  'BALRAJ  KUMAR',
#  'YU TE  KUO',
#  'KURUVILLA PARAPALLIL KURIAN',
#  'DEBRA LYNN LAGAPA',
#  'XUAN NGOC LAM',
#  'HENRICK  LAYOGAN',
#  'LOC TRUNG LE',
#  'THIEN BA LE',
#  'JESSICA MEGAN LEANO',
#  'JI YUL LEE',
#  'JUNG HO LEE',
#  'SUN YUN LEE',
#  'TIMOTHY CHANGWON LEE',
#  'YELEEN  LEE',
#  'AJAY KUMAR LEEL',
#  'MYRON HOWE LEW',
#  'MONICA CHEN LI',
#  'ZHONG YAN LI',
#  'HUNG HOT LIENG',
#  'ANDY  LIN',
#  'CHING-LIN  LIN',
#  'NAI ZAW LIN',
#  'PAUL YAO CHUNG LING',
#  'KANHKA  LINTHAVONG',
#  'PANGKALAMA  LOR',
#  'CHIBERLAINE IBARRA LUMAPAS',
#  'JEREMY TORRES MADRAZO',
#  'LAXMI SUDHEENDRA MALLYA',
#  'SANIA  MASOUD',
#  'SHAMA PERVEEN MASOUD',
#  'ELWON CHANDA MATHAVONGSY',
#  'RHONDA  MEININGER',
#  'ALEXANDER PHEKDEY MEN',
#  'MISAKO  MENARD',
#  'FARHAT NAZ MERCHANT',
#  'SERENA PAUL MIRCHANDANI',
#  'ZILLION ZEBULLUN MOE',
#  'PAW  MOO',
#  'YOSHIKO KIDD MOORE',
#  'LUISA  MOURA MUSZYNSKI',
#  'NOLA  NABOUNPAENG',
#  'JOHN YING NG',
#  'AN THANH NGUYEN',
#  'LENA MY NGUYEN',
#  'HALEY  NI',
#  'HWIL NOMN NIE',
#  'TEIGHLA NICOLE NORRIS',
#  'DANIEL KYUNGSEOK OH',
#  'PREETHI YOHANNAN PAIS',
#  'TESSY JOSEPH PALATHINKAL',
#  'JASMIN DABU PASCUAL',
#  'BHUMI ASWIN PATAK',
#  'ANIL MOHAN PATEL',
#  'ANJANABEN DILIPKUMAR PATEL',
#  'ARATI DIPAK PATEL',
#  'BADAL RAJESH PATEL',
#  'DILIP VITTHALBHAI PATEL',
#  'DIPAL GHANSHYAMBHAI PATEL',
#  'GORDHANBHAI HARAMANBHAI PATEL',
#  'JATINKUMAR  PATEL',
#  'JAYESHKUMAR RAOJIBHAI PATEL',
#  'KANCHANBEN BABARBHAI PATEL',
#  'KAVITA RUPAREL PATEL',
#  'KETAN GIRISHKUMAR PATEL',
#  'LAKHIBEN MAGANBHAI PATEL',
#  'NANDAN VINU PATEL',
#  'POOJA DARSHAN PATEL',
#  'RAMBHAI CHHOTABHAI PATEL',
#  'SAAJAN  PATEL',
#  'SAPNA S PATEL',
#  'SUDHABEN ISHWARBHAI PATEL',
#  'TULSI DARSHAN PATEL',
#  'DENISE E PATTERSON',
#  'SER GAY  PAW',
#  'MICHAELA VANDERPUTTEN PEARSON',
#  'EILEEN BABASA PEREZ',
#  'ANTHONY DUY QUANG PHAN',
#  'MU  PO',
#  'JOEL IBARRA QUINTOS',
#  'JUNE ROSE RAJAN',
#  'IZA LISETTE BORRAS REYES',
#  'ISAAC CLAY FUBAO RICE',
#  'ANLI ZUO RIVERA',
#  'MERIAM DAJUELA ROBERTSON',
#  'PARICHAT SUWANMANEE ROBINSON',
#  'BEE TA ROO',
#  'SARA REBECCA RUSSELL',
#  'QAMER  SABIR',
#  'CHRISTINA MARIA SAJU',
#  'ISAMI  SAKAI',
#  'BETHANY JOY SANFORD',
#  'MOLLY MARIE SCHEUMANN',
#  'JIWON MARION SEO',
#  'CINDY ANGELIQUE SHARPE',
#  'JULIA RENEE SHARPE',
#  'ARSHAD MAHMOOD SHEIKH',
#  'HONG KI SHIN',
#  'MOHAMMAD ALI-FAHIM SIDDIQUI',
#  'OVAIS FAHIM SIDDIQUI',
#  'SHOAIB FAHIM SIDDIQUI',
#  'ARSHIA  SIMKIN',
#  'AMARJOT  SINGH',
#  'HENRY  SOEWARDIMAN',
#  'EUL SIK SON',
#  'JEFF  SONG',
#  'BOUNTHOM SISAY SORSENGINH',
#  'MELODY DAOSAVANG SORSENGINH',
#  'SANK  SOUTHIPHONH',
#  'GURUMURTHY  SRINIVASAN',
#  'LIVING  STONE',
#  'ANNA  STUART',
#  'KASEV RAM SUNDAR',
#  'CHUN YEUNG JACKSON SZETO',
#  'MANJIT KAUR TAKHI',
#  'AUNG KYI THIN',
#  'CAROLYN ROSE THOMAS',
#  'SHINY  THOMAS',
#  'EMA JEAN BULAON THOMASON',
#  'YUSOON  THOR',
#  'THOMAS SEE KHONG TIONG',
#  'KENNY  TRAN',
#  'PHUONG V TRAN',
#  'LYNN CRYSTAL TRIEU',
#  'TRANG T TRIEU',
#  'JASON  TSENG',
#  'JOSHUA MAURICE BANKS TURNER',
#  'SUBBULAKSHMI  UPADRASTA',
#  'BOBBEE SONGKOUN VANNASANE',
#  'THAO MINH VO',
#  'MALA ASWANI WADHWANI',
#  'YA DAY MOO WAI',
#  'TRACY LEMONT WATLINGTON',
#  'MAUNG MYO WIN',
#  'GORDON DOLUNG WONG',
#  'YOOK NOOI WOON',
#  'LINGLING  XU',
#  'CHENG SI  YOU',
#  'NAZLA  ZAFAR',
#  'JIA MEI ZHANG',
#  'XUEYUN  ZHANG',
#  'BARRY GOROSPE ARCIAGA',
#  'ELIZABETH BAGANO BELL',
#  'RODOLFO  CABUCOS',
#  'CHAN SHONG CHANG',
#  'WILLIAM  CHEUNG',
#  'ZAWA  CHOUAYANG',
#  'WILLIAM HUI KANG CHU',
#  'ROMAN  DELACRUZ',
#  'GEORGE PULICAY DENIS',
#  'GAYLE CASTILLO HOFFER',
#  'TIMOTHY MITCHELL KEMPF',
#  'KALVIN KONG KUE',
#  'BOBBY  LEE',
#  'MATTHEW  LEE',
#  'PA JAI LEE',
#  'PICHEE  LEE',
#  'YUE KENG LEE',
#  'AMY  LOR',
#  'JOHN  LOR',
#  'XUAN VAN LY',
#  'CHAO YANG MCGLAMERY',
#  'FATEMEH HASHEMI MCINTYRE',
#  'SOM-SUN  MCKEE',
#  'MAHENDRABHAI CHHAGANBHAI PATEL',
#  'REKHABEN MAHENDRABHAI PATEL',
#  'GRACY M PAYNE',
#  'NASIN  SEE',
#  'JIMMY SAMSON TAN',
#  'MEILIN ALEXIS TAN',
#  'SALLY MOUNG TERN',
#  'LENNY LIEM THANH TRAN',
#  'IAN A TROUTMAN',
#  'BETTY  VANG',
#  'HOR  VANG',
#  'KEVIN DANNY VANG',
#  'SHAWN CHAIH VANG',
#  'TOUA  VANG',
#  'YANG YOUA VANG',
#  'JOUA  VUE',
#  'YANG MEE VUE',
#  'JASON  XAYAVONG',
#  'ANGELINA PAJDAWBHUV XIONG',
#  'KEE  XIONG',
#  'MAI SOUA XIONG',
#  'MYDUR  XIONG',
#  'PAI  XIONG',
#  'PETER  XIONG',
#  'STEVE TOU XIONG',
#  'TOULUE  XIONG',
#  'ZAITA  XIONG',
#  'BAO  YANG',
#  'CHEE NOU YANG',
#  'GE  YANG',
#  'JUDI  YANG',
#  'LENG  YANG',
#  'SHERRY XAME YANG',
#  'YIA  YANG',
#  'SUSAN O THORNTON',
#  'KONG CHENG CHANG',
#  'HOA QUOC CHAU',
#  'DEN  CHETH',
#  'ROMY BOLIBOL DOLLENTE',
#  'RUBY MAE SALDUA DOLLENTE',
#  'HOY LEE GREENE',
#  'AZEEM  HASSAN',
#  'VICTORIA ANN HUNTER',
#  'MICHELLE LYNN JOHNSON',
#  'KIM NGAN THI LE',
#  'JIM NHIAVUE LEE',
#  'CHANAMARONY  LIM',
#  'NANCY THI PHAM',
#  'HA NGOC TRAN',
#  'ADAM  VANG',
#  'SENG VUE VANG',
#  'YIMLEEJ ALEXANDER VANG',
#  'NANCY  XIONG',
#  'JACKLYN KALIA YANG',
#  'MAY LEE YANG',
#  'JOSE  BISCAYA',
#  'TRAVIS EVERETT BROWN',
#  'RAJEEV MANUBHAI CHAUHAN',
#  'SUSAN  CHONG',
#  'DAVID  FOURNIER',
#  'CYNTHIA KASTL HARLESS',
#  'JEFFREY G MANUEL',
#  'JOSEPH  NGUYEN',
#  'CHANANPORN  WELLER',
#  'NANCY EMI YAMASHITA',
#  'BRIAN  ZHENG',
#  'MAX ROSWELL BROWN',
#  'HENRY HONG-LI CHUANG',
#  'ESTHER GALOPE CLARK',
#  'BIC THI THANH LE',
#  'KEITH JUNG MINN',
#  'MARIA CABANOS ACELLO',
#  'LUONG LIEU BROWN',
#  'MARIA ISABEL CARCALLAS-KOSIC',
#  'WENDY ANNA DU',
#  'CO VAN HUYNH',
#  'YOU HONG LIN',
#  'OFELIA RAMOS NEAL',
#  'HANAA BINTI NIK RUSHDI',
#  'SUNIL ANAND PATEL',
#  'AVELINA D SHEPPARD',
#  'VISWANATHAN  SWAMINATHAN',
#  'JAE JIN JANG BAZEMORE',
#  'RONNIE BROWN BOYD',
#  'NASHUN NAQUAN FLEETWOOD',
#  'AMELIA TEVES GAZA',
#  'KAREN  GUO',
#  'SHING TAT LAU',
#  'ADRIENNE MARIE ORBITA',
#  'LOURDERICO RAMONAL PAGARA',
#  'ARCELIETO SANCHEZ QUIACHON',
#  'ELIZABETH TIFFANY LYNN SPELLMAN',
#  'RAMON ISLA UNICRUZ',
#  'PAUL  BROOKS',
#  'EVANGELINE CABANTING DAUGHERTY',
#  'SHUSONG  JIANG',
#  'TRINH TRUONG LANCASTER',
#  'SONNEY SENGSOURIYA PHANNOUVONG',
#  'RAYMUND SAN AGUSTIN ACAYAN',
#  'ROGELIO ABRIGO ACERA',
#  'SATINDER  AHUJA',
#  'SARA HEATHER ANNESI',
#  'EDNA PEARSON AVISO-SECKEL',
#  'SONALI KHOT BATISH',
#  'JAIDENIA BULAGA BAUCOM',
#  'DANIEL KING BIGHAM',
#  'LORD BADDEN EUGENIO BOCTOT',
#  'TROY CHRISTOPHER BOHLER',
#  'CONSTANCE  BROUGHTON',
#  'MANISA  BUNYASIRI',
#  'MICHAEL ALAN CARVER',
#  'MARY SUK-YING CHAN',
#  'EDWARD KUOPI CHAO',
#  'CHARLOTTE  CHIN',
#  'SUNG HAN CHON',
#  'ANN ELIZABETH COLLINS',
#  'ANNA LYNETTE CONSTANTINE',
#  'PAVAN KUMAR DASARI',
#  'ANN NERY DEL ROSARIO',
#  'HEMA NIHAL DESILVA',
#  'ANNIE SHEN DOUGHERTY',
#  'JENNIFER LYDIA DOYLE',
#  'OUBONVANH PHOMMAVANH EMMONS',
#  'JEFFREY STEVEN ENG',
#  'LIAN LUCIA FARRUGGIO',
#  'SUZANNE YEAGER FOWLER',
#  'ROSA BALAYSOCHE FULTON',
#  'ROBERT JOSEPH GRANT',
#  'DEVON MEI-AN GREIG',
#  'KATHY  HA',
#  'JOHN NEIL HOLTON',
#  'EMMA  HOM',
#  'TRONG DUC HUYNH',
#  'LOUISE JESSICA JACOBSEN',
#  'MYONG SUK JENSEN',
#  'JAMES ALLEN JOHNSTON',
#  'HOLLY LYNNE JONES-PICKERELL',
#  'DAISY BAUTISTA KEENAN',
#  'NIGORA  KISSAM',
#  'CHANTANA  KREAMER',
#  'YUVITA  KURNIAWAN',
#  'WILLIAM JOSEPH LAGALA',
#  'SAMANTHA LEI LANEVI',
#  'HOANG VAN LE',
#  'MAU CONG LE',
#  'AUSTIN KUN WOO LEE',
#  'DANNY  LIN',
#  'MENGNAN  LIN',
#  'CHRISTINA  LIU',
#  'XIAOJING  MA',
#  'KHIEM DUC MAI',
#  'TERRY TAKASHI MATSUMURA',
#  'DINESH ASHVINIKUMAR MEHTA',
#  'LEONILA PUREZA MERCER',
#  'CAMILA  MESSERSMITH',
#  'MARY RUTH ACHAS MOERI',
#  'SULTAN  MOHIUDDIN',
#  'VIVIEN FIFI MONNIE',
#  'ANGELA  MUELLER',
#  'JAN KAING NG',
#  'JIM VAN NGUYEN',
#  'KAREN KIM NGUYEN',
#  'NANCY  NGUYEN',
#  'QUYNH TRAM THI NGUYEN',
#  'TUAN MINH NGUYEN',
#  'UYEN TO NGUYEN',
#  'SUKAWADEE MING PETCHRAKRAI',
#  'TRAVIS NIEDERBERGER PETRALBA',
#  'JUSTIN MARK PETRONACI',
#  'ANH TUONG PHAM-BAGINSKI',
#  'DONG VAN PHAN',
#  'MONICA ATIQUE RAHMAN',
#  'PADMINI  RAVINDRANATHAN',
#  'CARRIE SUSANNA REED',
#  'SUNG HYON REINHOLD',
#  'PARAMIN  RUENBANTHOENG',
#  'KHAM  SENGSOU',
#  'SHIAO-WEN NANCY  SHEN',
#  'JARED KELLY SIPE',
#  'ROSNANI BINTI YAHYA STOKES',
#  'ANNA YOUNG STOUDER',
#  'ROBERTO MARBIBI SUDARIO',
#  'HOAN GIE TAN',
#  'NALINEE  TANTAYOPIN',
#  'JACEN ZAKNAFEIN THOMAS',
#  'OLIVIA KUEN TONG',
#  'HAZEL ELAINE TRINIDAD',
#  'CARMELITA RONQUILLO TUCKER',
#  'RONALD HENRY WAIDLICH',
#  'PILAR MONICA WALING-MAY',
#  'JANET SANTOS WHITE',
#  'CONNIE BROWN WILLIAMS',
#  'SHONET ALISON WONG',
#  'JUNG OK WOOLCOTT',
#  'AMY JANE YAGI',
#  'KEYOU LAI YAN',
#  'CHUN DONG YANG',
#  'YUN JIN YANG',
#  'MACHIKO YAMADA YEUNG',
#  'KANG IM YI',
#  'PHYLLIS GUIPING YIN',
#  'ALLAN KEN YOSHIMURA',
#  'ALBERT  YOUNG',
#  'ANNA GA-WAI ZENG',
#  'YAN  ZHOU',
#  'YING  ZHU',
#  'SHAKIL  AHMAD',
#  'BRIAN JU AHN',
#  'SAIM  ALAM',
#  'RAZA SHAUKAT ALI',
#  'SHARA POLON AMBROS',
#  'SWEETY  AMIN',
#  'ROBBY EDWARD AMMONS',
#  'TARA SAYURI ANDREWS',
#  'HARIVOLA JOELLIE ANDRIANAMALASATA',
#  'ARDEN LEE ANGLISS',
#  'STEVEN  AR',
#  'Y BERLINIA ARAN',
#  'SEETA  ARUNDHATI',
#  'ROBERT LYNN ATKINS',
#  'MARY ACE LAVILLES BAGGOTT',
#  'MATTHEW TAKAO BALLOGDAJAN',
#  'KENNETH PAUL MALUTE BANGONAN',
#  'MYLENE UMINGA BAQUIRAN',
#  'MARIA-TERESA  BEATHARD',
#  'RUDRANATH  BEHARRYSINGH',
#  'NOBEL ABENES BELLOSILLO',
#  'ALEXANDER ROBERT MASAO BERNET JONES',
#  'MEHUL KANTILAL BHAKTA',
#  'RONY  BOE',
#  'SIRIWATTHANA NAHIRAN BORNEMANN',
#  'JESSICA LEE BOUN',
#  'HYUN CHAE BOWEN',
#  'JESSICA LYNN BOWER',
#  'ANNE CORA BOWERS',
#  'YAEKO  BOWLER',
#  'ELEDRODITA AMOIN BYRNE',
#  'MARIANO BALANDRA CAINTO',
#  'CHRISTIE MARIE CALAYCAY',
#  'ADRIANNE  CHANG',
#  'BRYAN  CHANG',
#  'CLARA KIM CHAY',
#  'HUI QIN CHEN',
#  'YUN YONG CHEN',
#  'CHEATAK  CHHORN',
#  'EVELYN SHUN CHIANG',
#  'JUNG SOON SOON CHO',
#  'ABIGAIL CATHARINE CHU',
#  'CALVIN YEN CHU',
#  'LEAH  CHUNG',
#  'SONJUE  CHUNG-KOLTSOV',
#  'KATHERINE MEERAN CICALE',
#  'FRANCEEN MEI-LING CLARK',
#  'WADE ANDERSON CLARK',
#  'FREDERICK JAMES CLOOS',
#  'TERESITA ALARCON CRAIG',
#  'ANNA CHRISTINA CRAWFORD',
#  'MANESH S DAGLI',
#  'ANIRUDDHA  DAS',
#  'HARESH VANSANTRAI DAVE',
#  'GREGORY ALLLEN DAVIS',
#  'WILFRED P DAWI',
#  'THILANI FRANCES DE SILVA',
#  'DOROTHY F DELA CRUZ',
#  'JAY JAGDISHBHAI DESAI BUTLER',
#  'LEE  DIAZ',
#  'HANH  DINH',
#  'PEGGE MINDA DIXON',
#  'LUAN QUANG DO',
#  'CHIME  DOLMA',
#  'MARY EMMELINE DUFT',
#  'SIONY  DULAY',
#  'MELISSA  DUONG',
#  'TRANG THUY THI DUONG',
#  'SIEGFRED DAGADAG DUPYAWON',
#  'AMY KO EARNHART',
#  'MARTHA ANNE NUNNALLY EASON',
#  'KAE ADAM EISDORFER',
#  'JENNY LOU FAMA ESCANO',
#  'CHRISTOPHER G M FARGO-MASUDA',
#  'BRIANNA PAIGE FISHER',
#  'EMIKO EMILY FLYNN',
#  'CLAUDIA IN SOOK FORTES',
#  'KHUN  FOXX',
#  'ALICIA B FREUND',
#  'NHU-MAI NGOC FRIEDMAN',
#  'THERESA LIE-CHUN FU',
#  'CATTLEYA BURAPAVONG GAINES',
#  'NANCY MERCULLO GALSIM',
#  'YINGQIU  GAO',
#  'AMARRA USMAN GHANI',
#  'FRANCESCA PAULIEN GILLETTE',
#  'WAIDA LIU GODFREY',
#  'CHRISTIANNE LORRAINE GOFF',
#  'ANIL KUMAR GOLI',
#  'HENRY  GONG',
#  'NANCY LIAN GONG',
#  'GLORIA SATO GREENE',
#  'SHULUN  GU',
#  'XINNI  GUO',
#  'KIRAN  GUPTA',
#  'VINENDRA  GUPTA',
#  'MINNIE  GURAM',
#  'MADAN P GURUKAR',
#  'CHAO  HAN',
#  'HYUN JA HAN',
#  'LEI  HAN',
#  'ASHLEY MARIE HAYNES',
#  'KAY KATSUKO HELWIG',
#  'CASEY JAMES TOLA HERREN',
#  'TUONG VINH HO',
#  'CHOONG PYO HONG',
#  'JENNIFER ANN HOSLER',
#  'LI-YUEH  HU',
#  'KOLBY BLAKE HUNTER',
#  'SOKKHIM  HUOT',
#  'SAVANNAH NICOLE PEYTON HUTSELL',
#  'AESAN  IM',
#  'JAYSON SOOYOUNG IM',
#  'MONEEB  IRFAN',
#  'JOHANES  IRVAN',
#  'KIM HUONG IRVING',
#  'NOWSHIN  ISLAM',
#  'SARAH MAE JACKSON',
#  'SUE ANNA JOE',
#  'MARIA VICTORIA JOHNSON',
#  'NEIL ALLEN JOHNSON',
#  'JEANIE LUMONGSOD JONAS',
#  'ERICK MORRIS JORDAN',
#  'PONG CHOL JUHNN',
#  'TERUMI TERI KADIN',
#  'KANTHILATA  KAHADUWE',
#  'JUNG SOOK KANG',
#  'CALEB  KAO',
#  'YEE  KAO',
#  'DAISY TENG KARASEK',
#  'KATE  KE',
#  'GAIL PAULA KEYES',
#  'QURAT UL AIN NAYYAR KHAN',
#  'YASH DARSHAN KHATAVKAR',
#  'PETER  KHOUNCHANH',
#  'BRYAN VAUGHN KILLIAN',
#  'EUNKYOUNG  KIM',
#  'HAN YONG KIM',
#  'HANNAH  KIM',
#  'IRIS ARIE KIM',
#  'JIN KAK KIM',
#  'KAE SOON KIM',
#  'KYONG WHAN KIM',
#  'OK K KIM',
#  'TONG WON KIM',
#  'YOUNG EUN KADY KIM',
#  'MIMI PATRICIA KOONTZ',
#  'CALAE CHAN MI KOPOCS',
#  'VIDYA BAKKI KUDVA',
#  'KESHAV DHILIP KUMAR',
#  'MANOJ  KUMAR',
#  'RAYSHAN  LAI',
#  'ALEXANDER JUNKEE LAMSON',
#  'RENALYN CASIPE LANZA',
#  'MARIKA LE LAPHAM',
#  'SOON YUNG TAYLOR LARSEN',
#  'DONALD LYNIAL LATHAM',
#  'BAO TRAN THI LE',
#  'KYE TANONG LEAMMOOKDA',
#  'ALEXANDER HSIN YEN LEE',
#  'DEBORAH YOUNG SUP LEE',
#  'EDWARD KAM-HOI LEE',
#  'IL SUNG LEE',
#  'JAE WON LEE',
#  'KYUNG JA JA LEE',
#  'MOORYOL  LEE',
#  'PHILLIP SIN CHIH LEE',
#  'STEPHANIE PEII LEE',
#  'TIMOTHY YATMING LEE',
#  'YONG HWI LEE',
#  'DEBORAH Y LEE-SIMMONS',
#  'JACQUELINE  LETRAN',
#  'JIN YAO LI',
#  'LILIANE TIERNEY LI',
#  'RUI YUN  LI',
#  'XIN ZI LI',
#  'ZU QIN LI',
#  'JAMIE LYNN LIEHR',
#  'EMILY CHAE YOUNG LIM',
#  'BERHAM MATTHEW LIN',
#  'DAN BIN LIN',
#  'JENNIFER  LIN',
#  'SHANG A LIN',
#  'YI  LIN',
#  'DONG  LIU',
#  'STEVEN  LO',
#  'CAMERON EDWARD GIN WAI LOW',
#  'ERLYNN LAURILLA LUNA',
#  'ANNIE NOELANI LUNSFORD',
#  'SACHIKO LYNE LUNSFORD',
#  'CATHERINE JENG-CHIN MA',
#  'MATTHEW RABINDRA MACON',
#  'KEYA  MAITRA',
#  'CHENDA SREY MAK',
#  'SURATTIYA SINTHAWACHIWA MALASZEWSKI',
#  'JEMIMA LABI MALOTE',
#  'CHOLVICH MAGNUM MANGKANG',
#  'EVE SHOSHANA MARKOVITZ',
#  'ELLIE SUNITA MARTY',
#  'MARK ALEX HERNANDEZ MASANGKAY',
#  'JENNY  MAY',
#  'MERILYN YAON MCCRACKEN',
#  'ERIN JEAN MCGRADY',
#  'MARY ISABELLA MCGRAIN',
#  'VIMI KHANNA MCKEITHAN',
#  'KERRIANNE KAU MCMURDO',
#  'LENNEL IBARROLA MENDOZA',
#  'KEIKO TANAKA MERL',
#  'ALICIA CELONISE MERRILL',
#  'LIA IRENE MESSERSMITH',
#  'FAKHAR MAHMOOD MIAN',
#  'LIZA VILLAMOR MILLER',
#  'MORIAH HOPE WILKINSON MILLER',
#  'BYUNG IM MIN',
#  'KATHERINE KYOUNGHEE MIN',
#  'DANILO M MINDO',
#  'EGBERT LOUIS MING',
#  'AMY PRAKASH MODY',
#  'MARLON NICHOLAS MOO YOUNG',
#  'CHELSEA MARIE MOUNTFORD',
#  'MAKENZY LIEN MULL',
#  'DUCKJUNG JANE MUSGRAVE',
#  'KAZUO  NAKAZAWA',
#  'PAZ BLANCA VALENCIA NAVIDAD',
#  'WANN  NEAR',
#  'HANH NGOC NGO',
#  'TRINH KIEU NGO',
#  'HUNG TAN QUOC NGUYEN',
#  'LARA BICH THAO NGUYEN',
#  'LILY  NGUYEN',
#  'NGUYEN VAN NGUYEN',
#  'NHUT QHM NGUYEN',
#  'THAO DANG KIM PHUONG NGUYEN',
#  'TRINH LE PHUONG NGUYEN',
#  'GRACE JUNE PING NICKLAS-MORRIS',
#  'MEAH HADASSAH HUAZHU NISENSON',
#  'JOSHUA SUGENE OH',
#  'KENNEDY MEILEIGH ORMOND',
#  'DAVID LEE ORTMAN',
#  'EMMA YIN PAGE',
#  'LEONARDO RALA PALACIO',
#  'NATALIE YOULAN PAPPAS',
#  'HENRY WOO PARK',
#  'CHANDRIKA MAGAN PATEL',
#  'DARSHAN KAMLESHKUMAR PATEL',
#  'FORAM NIRMAL PATEL',
#  'JAYANTILAL NATHALAL PATEL',
#  'KIRTI HASMUKH PATEL',
#  'MAHENDRAKUMAR CHIMANLAL PATEL',
#  'MINAXIBEN JEKISONDAS PATEL',
#  'MRUGESH  PATEL',
#  'PINAL SUBHASH PATEL',
#  'POONAM ATUL PATEL',
#  'PRASHANT P PATEL',
#  'PUNAMBMAI TULSIBHAI PATEL',
#  'RADHA PIYUSHKUMAR PATEL',
#  'SHOBHANA KIRITBHAI PATEL',
#  'SHRUTI S PATEL',
#  'HA BICH PHAM',
#  'ENRIQUE PANGILINAN PINEDA',
#  'MICHAEL JOSEPH POLPRASERT',
#  'WANVISA KOONGNOO PORTER',
#  'LISA C PRYOR',
#  'KARINA  QUERAL',
#  'WADIATUR  RAHIM',
#  'ADAM NANHAY RAMPERSAUD',
#  'ERLINDA S REESE',
#  'ABRAHAM OBENIETA RING',
#  'JOANNE LOUISE ROBERT',
#  'ENRIQUE T RODRIGUEZ',
#  'LINDA FRANCES RUSSELL',
#  'SHELINA FIDALI SAJU',
#  'SARAVANAKUMAR  SANKARAN',
#  'CHERYL ANN SARMIENTO',
#  'YASUKO MORIYA SATO',
#  'CZENGI ERRAWAN SAWADIVONG',
#  'EMMA ISABELLE SCHNEIDER',
#  'ELIZABETH M SCHULTZ',
#  'LISA CHOE SCOTT',
#  'DEBBIE  SET',
#  'CAITLIN C SEXTON',
#  'NIGHAT ABDULLAH SHAH',
#  'SANA  SHAKIL',
#  'SARAH GLADYS SHAO',
#  'AMY WOO-YUN SHUEY',
#  'ANDREW GRAHAM SIZEMORE',
#  'AMRYN  SOLDIER',
#  'CHIYEON DIANE SONG',
#  'MEHUL TRIBHOVANDAS SONIGRA',
#  'SIVENG VY SPENCE',
#  'ANGELA HOPE LAKE SPRAGG',
#  'SURABHI  SREESHA',
#  'DANY  SREY',
#  'CHANPHEN  SRISARAJIVAKUL',
#  'ALICE KIMBERLY STEARNS',
#  'DHARMINA  SUBRAMANIAM',
#  'THANH-TRUC THI SULAIMAN',
#  'AMANDA ALLIEN VIVIAN SULLIVAN',
#  'AMANDA ALLIEN VIVIAN SULLIVAN',
#  'MONA DIANE SURRETT',
#  'JACKIE  TA',
#  'ZAUR SAMED OGLU TAGHIYEV',
#  'JERRY JENNDONG TANG',
#  'ALFRED NUGUID TENORIO',
#  'VIVIAN MUNGCAL TENORIO',
#  'JERRY S TERAUCHI',
#  'LAL LIAN THANGA',
#  'WARREN LEE THANMITHAK',
#  'ROY THYON CHRISTOPHER THOMAS',
#  'RENALYN CASIPE TOWNLEY',
#  'EMILY  TRAN',
#  'HONG THUY THI TRAN',
#  'JIMMY VI TRAN',
#  'KIM LOAN THI TRANG',
#  'PRITAL DILIP TRIVEDI',
#  'ALLISON SHIN-WEIN TSAY',
#  'TIM ROBERT TSURUTANI',
#  'IRENE PARK ULRICH',
#  'STEPHANIE SO YUNG VAN CAMP',
#  'MAI CHEE VANG',
#  'DANA MARIE VILLALAS',
#  'JEFFREY TIEN VO',
#  'NAM DAI VO',
#  'DAVID  VU',
#  'THUY NGA VU',
#  'MARIA ESTELA CORPUZ WAGNER',
#  'JENNIFER MARIKO WALKER',
#  'DALE ROBERT WALLACE',
#  'JULI RUTH WALLEN',
#  'DEBORAH ANNE WHEELER WALTMAN',
#  'CINDY LIHUA WANG',
#  'LIHUAN  WANG',
#  'SABRINA D WANG',
#  'NORMA CLARO WASSON',
#  'CINDY MAISEE WEBSTER',
#  'JOYCE  WEI',
#  'SARAH LIN MIAO WEISS',
#  'SALVACION FIRMANES WESTFALL',
#  'JEAN H WILSON',
#  'ANGELDEEP KAUR WOLFE',
#  'ALLEN JOSEPH WON',
#  'MAE  WONG',
#  'OSCAR PETER WONG',
#  'JOHN MICHAEL WRIGHT',
#  'PIA MARIE TUMANG WUERFEL',
#  'JACOB  YANG',
#  'PETER  YANG',
#  'GUANG  YAO',
#  'GUANGBIN  YE',
#  'HOI NING KATHERINE YEUNG',
#  'HEISOOK  YIM',
#  'YIWEN  YIN',
#  'MELANIE EUNHYE YOON',
#  'HWAN CHIN YU',
#  'STEPHANIE KAYLYN YU',
#  'BRIAN XICHENG ZHANG',
#  'BEIBEI  ZHOU',
#  'JIAO XIAN ZHUO',
#  'FELICIA  ZI',
#  'AGHA SARMAD ABBAS',
#  'NERISSA REALIZAN AGUNIAS',
#  'FAHMIDA  AHMAD',
#  'JITENDER  AMAR',
#  'ANNA FRISA AUSPITZ',
#  'JENNY LU BAQUIAX',
#  'LUX FLORES BELTRAN',
#  'TINA VUE BERRY',
#  'MELINA R BOYER',
#  'BAY  CHA',
#  'TOU  CHANG',
#  'LUCY  CHASENGNOU',
#  'RONNY  CHASENGNOU',
#  'YANI  CHEN',
#  'KEVIN LEO CHENG',
#  'CHI PONG  CHEUNG',
#  'KASIA  CHUE',
#  'SEALAMANE  CHUE',
#  'XA  CHUE',
#  'ZARANIE ALTHEA  COLLADO',
#  'LOUIS ROBERT COSSEY',
#  'JUDY MI YUNG ECKLUND',
#  'CARLO FERNANDEZ ENCARNACION',
#  'OFELIA LOBUSTA FISHER',
#  'EDWARD  GEE',
#  'CHARLENE AGNES GOODING',
#  'ALLEN  HANG',
#  'BELINDA CHEEVU HANG',
#  'CHINA GAONOU HANG',
#  'ELIZABETH  HANG',
#  'GARY  HANG',
#  'KOUA  HANG',
#  'LIVRE  HANG',
#  'MICHELLE VIVIAN HANG',
#  'MUA KONGMENG PHILLIP HANG',
#  'PAMELA CHANG HANG',
#  'SINDY L HANG',
#  'THONG  HANG',
#  'MARION MAGNO HAWKINS',
#  'KAO NONG HER',
#  'LOREENA YUTANGOO HERMITANIO',
#  'DIAMOND CHARDU HEU',
#  'ALI  IFTIKHAR',
#  'NUREEN  IKRAM',
#  'RAJIVE MUKUND JHAVERI',
#  'RANJANA SHARMA JOSHI',
#  'BAO HANG KHANG',
#  'KAITLYN SUNAE KIM',
#  'FLORDELIZA INFANTE KORICH',
#  'CHOU  KU',
#  'KONGMENG YONGCHUE KUE',
#  'TIA MARY KUE',
#  'CHAI SOUA LEE',
#  'CHENFOI  LEE',
#  'CHUEYEE JOSHUA LEE',
#  'ELIZABETH DER LEE',
#  'JIM  LEE',
#  'KABAO  LEE',
#  'KENG  LEE',
#  'KIMZENN  LEE',
#  'LEE XANG LEE',
#  'MAI BAO LEE',
#  'MAI NHIA LEE',
#  'MARCIE  LEE',
#  'MIKE  LEE',
#  'PHER  LEE',
#  'PHOUA  LEE',
#  'SHENG  LEE',
#  'TOUA  LEE',
#  'TOUBEE  LEE',
#  'VUE PAO LEE',
#  'YANG  LEE',
#  'YUE PENG LEE',
#  'ZONG SEENHIA LEE-VANG',
#  'SAVANG  LEUTHONGCHAK',
#  'SAU MUI  LIU',
#  'RENATO CANDELARIA LIVAS',
#  'BELL  LO',
#  'KAOGEYIA  LO',
#  'KATIE MAYXEA LO',
#  'MELINDA SHANG YING LO',
#  'NA DA BLE LO',
#  'NHIA PAO LO',
#  'PHOUA YANG LO',
#  'SHOUAPHENG NICHOLAS LO',
#  'THAI BILLY LO',
#  'YOUNG THAO LO',
#  'BLIA YANG LOR',
#  'CHAI VANG LOR',
#  'CHEE  LOR',
#  'DORA YIECHEE LOR',
#  'JACOB HMOO LOR',
#  'JOE  LOR',
#  'KA ZOUA MARY LOR',
#  'KAO  LOR',
#  'LAURA  LOR',
#  'LEE FUE LOR',
#  'MATEO NEU LOR',
#  'PACHIA KATRINA LOR',
#  'STEVE YENG LOR',
#  'TOWYENG  LOR',
#  'TYLER MOUA LOR',
#  'DAVID TIMOTHY LUU',
#  'BRIDGET GO NAG MOUA',
#  'CHARLIE TOU FUE MOUA',
#  'DAU YANG MOUA',
#  'GOLIA  MOUA',
#  'JIM ZEU KEU MOUA',
#  'JOSHUA TOULONG CHOUALU MOUA',
#  'MEE THAO MOUA',
#  'MICHAEL PLHAIB MOUA',
#  'PA  MOUA',
#  'XAO  MOUA',
#  'MYRNA SANGO NAVALES',
#  'SHERINE TRESA NEDUMCHIRA',
#  'PAHUA  NEWSOME',
#  'ANTHONY LONS NGO',
#  'BOUNCHANH  NIVANH',
#  'PHETOUDONE PAT NIVANH',
#  'TONY  NIVANH',
#  'JUANIFE TINDUGAN OSBORNE',
#  'JAINISHKUMAR MAHESHKUMAR PATEL',
#  'JAYESHKUMAR BHANUBHAI PATEL',
#  'PRIKESHKUMAR RAMBHAI PATEL',
#  'SAHIL JAIMIN PATEL',
#  'VASANT MANILAL PATEL',
#  'DILYS  PAU',
#  'ANABEL SOLORIA PETILUNA',
#  'BASILIO BURGOS PETILUNA',
#  'FILBERT SOLORIA PETILUNA',
#  'JEANIE LO PHASINAME',
#  'LINTHONG LIN PHIMMACHAK',
#  'JENELYN BIGCAS PITTILLO',
#  'ANGELINE VIVIAN PLEASANT',
#  'DENYSE THEA LA CHAPELL POARCH',
#  'MATTHEW JAMES POWLEY',
#  'FUMIMASA  SATAKE',
#  'JOSEPH SEERALAN SAVARIMUTHU',
#  'XIAPHERUS DOUDY SAYARATH',
#  'ERIK SANTIAGO SEPEZ ITZOL',
#  'SHETAL PARIN SHAH',
#  'TAHERA ALIKHAN SHAH-KHAN',
#  'JASON  SHAIHOR',
#  'SHRISTI BABA SILWAL',
#  'SCOTT  SINPAPORN',
#  'PHAENGSAK  SITTHIPHANH',
#  'ALYSA PHIMPHA SOMCHANH',
#  'ELEANOR CO SULLIVAN',
#  'YU  SUN',
#  'JENITA  TANDUKAR',
#  'AMANDA HER THAO',
#  'BOUNBAI  THAO',
#  'CHOUA  THAO',
#  'DESTINY HLI THAO',
#  'KATHY  THAO',
#  'KOLA  THAO',
#  'LA SHEKOU THAO',
#  'MAY KOU THAO',
#  'MELODY LEE XIONG THAO',
#  'PA YING THAO',
#  'XANDHER KHON MONG THAO',
#  'ANGELA MAI THOR',
#  'CHEN  THOR',
#  'JOUA BEE THOR',
#  'SAMPSON X THOR',
#  'FLORENA ORFANEL TRIPLETT',
#  ...]
